# %%
import os
import glob
import numpy as np
from matplotlib import pyplot as plt
from osgeo import gdal
import pandas as pd
from keras.utils import to_categorical
import tensorflow as tf
from sklearn.utils import class_weight
import random

# %%
train_images = []
image_names = glob.glob(r"G:\Mi unidad\CG_Tesis_UrielMendoza\metodologia\datos\satelitales\Wildfire Burn Severity Assessment\Training\Image\Post/*.tif")
image_names.sort()
for img_path in image_names:
      tiff_image = gdal.Open(img_path, 0)
      band7 = tiff_image.GetRasterBand(7).ReadAsArray()
      band8 = tiff_image.GetRasterBand(8).ReadAsArray()
      band9 = tiff_image.GetRasterBand(9).ReadAsArray()

      X = np.stack((band9, band8, band7), axis=-1)
      train_images.append(X)

train_images = np.array(train_images)
print(np.mean(train_images))
X_train = train_images
print(X_train.shape)

train_masks = []
image_names = glob.glob(r"G:\Mi unidad\CG_Tesis_UrielMendoza\metodologia\datos\satelitales\Wildfire Burn Severity Assessment\Training\Mask/*.tif")
image_names.sort()
for img_path in image_names:
   tiff_image = gdal.Open(img_path, 0)
   band1 = tiff_image.GetRasterBand(1).ReadAsArray()
   train_masks.append(band1)

train_masks = np.array(train_masks)
y_train = train_masks
print(y_train.shape)

y_train_cat = to_categorical(train_masks, num_classes=4)
y_train_cat = y_train_cat.astype(int)
print(y_train_cat.shape)
# Out:
# c:\Users\urielm\anaconda3\envs\Wildfire-Burn-Severity-Assessment\lib\site-packages\osgeo\gdal.py:311: FutureWarning: Neither gdal.UseExceptions() nor gdal.DontUseExceptions() has been explicitly called. In GDAL 4.0, exceptions will be enabled by default.
#   warnings.warn(
# 1283.7584615587612
# (690, 256, 256, 3)
# (690, 256, 256)
# (690, 256, 256, 4)

# %%
train_images_pre = []
image_names = glob.glob(r"G:\Mi unidad\CG_Tesis_UrielMendoza\metodologia\datos\satelitales\Wildfire Burn Severity Assessment\Training\Image\Pre/*.tif")
image_names.sort()
for img_path in image_names:
      tiff_image = gdal.Open(img_path, 0)
      band7 = tiff_image.GetRasterBand(7).ReadAsArray()
      band8 = tiff_image.GetRasterBand(8).ReadAsArray()
      band9 = tiff_image.GetRasterBand(9).ReadAsArray()

      X = np.stack((band9, band8, band7), axis=-1)
      train_images_pre.append(X)

train_images_pre = np.array(train_images_pre)
print(np.mean(train_images_pre))
# Out:
# 1283.7590900587

# %%
train_images_nbr = []
image_names = glob.glob(r"G:\Mi unidad\CG_Tesis_UrielMendoza\metodologia\datos\satelitales\Wildfire Burn Severity Assessment\Training\NBR/*.tif")
image_names.sort()
for img_path in image_names:
      tiff_image = gdal.Open(img_path, 0)
      band1 = tiff_image.GetRasterBand(1).ReadAsArray()
      band2 = tiff_image.GetRasterBand(2).ReadAsArray()
      band3 = tiff_image.GetRasterBand(3).ReadAsArray()

      X = np.stack((band1, band2, band3), axis=-1)
      train_images_nbr.append(X)

train_images_nbr = np.array(train_images_nbr)
train_images_nbr = np.nan_to_num(train_images_nbr, nan=0.0)
print(np.mean(train_images_nbr))
# Out:
# 3.1838393

# %%
#Sanity check, view few images
import random
import numpy as np
image_number = random.randint(0, len(train_images)-1)
plt.figure(figsize=(12, 6))
plt.subplot(121)
plt.imshow(np.reshape((train_images[image_number, :, :, 2]), (256, 256, 1)))
plt.subplot(122)
plt.imshow(np.reshape(train_masks[image_number], (256, 256, 1)))
plt.show()
print(image_number)
# Out:
# 478

# %%
test_images = []
image_names = glob.glob(r"G:\Mi unidad\CG_Tesis_UrielMendoza\metodologia\datos\satelitales\Wildfire Burn Severity Assessment\Testing\Image\Post/*.tif")
image_names.sort()
for img_path in image_names:
      tiff_image = gdal.Open(img_path, 0)
      band7 = tiff_image.GetRasterBand(7).ReadAsArray()
      band8 = tiff_image.GetRasterBand(8).ReadAsArray()
      band9 = tiff_image.GetRasterBand(9).ReadAsArray()

      X = np.stack((band9, band8, band7), axis=-1)
      test_images.append(X)

test_images = np.array(test_images)
print(np.mean(test_images))
print(test_images.shape)

test_masks = []
image_names = glob.glob(r"G:\Mi unidad\CG_Tesis_UrielMendoza\metodologia\datos\satelitales\Wildfire Burn Severity Assessment\Testing\Mask/*.tif")
image_names.sort()
for img_path in image_names:
   tiff_image = gdal.Open(img_path, 0)
   band1 = tiff_image.GetRasterBand(1).ReadAsArray()
   test_masks.append(band1)

test_masks = np.array(test_masks)
print(np.unique(test_masks))

y_test_cat = to_categorical(test_masks, num_classes=4)
y_test_cat = y_test_cat.astype(int)
print(y_test_cat.shape)
print(np.unique(y_test_cat))
# Out:
# 1314.3571367617008
# (36, 256, 256, 3)
# [0 1 2 3]
# (36, 256, 256, 4)
# [0 1]

# %%
test_images_pre = []
image_names = glob.glob(r"G:\Mi unidad\CG_Tesis_UrielMendoza\metodologia\datos\satelitales\Wildfire Burn Severity Assessment\Testing\Image\Pre/*.tif")
image_names.sort()
for img_path in image_names:
      tiff_image = gdal.Open(img_path, 0)
      band7 = tiff_image.GetRasterBand(7).ReadAsArray()
      band8 = tiff_image.GetRasterBand(8).ReadAsArray()
      band9 = tiff_image.GetRasterBand(9).ReadAsArray()

      X = np.stack((band9, band8, band7), axis=-1)
      test_images_pre.append(X)

test_images_pre = np.array(test_images_pre)
print(np.mean(test_images_pre))
print(test_images_pre.shape)
# Out:
# 1314.3589101720738
# (36, 256, 256, 3)

# %%
test_images_nbr = []
image_names = glob.glob(r"G:\Mi unidad\CG_Tesis_UrielMendoza\metodologia\datos\satelitales\Wildfire Burn Severity Assessment\Testing\NBR/*.tif")
image_names.sort()
for img_path in image_names:
      tiff_image = gdal.Open(img_path, 0)
      band1 = tiff_image.GetRasterBand(1).ReadAsArray()
      band2 = tiff_image.GetRasterBand(2).ReadAsArray()
      band3 = tiff_image.GetRasterBand(3).ReadAsArray()

      X = np.stack((band1, band2, band3), axis=-1)
      test_images_nbr.append(X)

test_images_nbr = np.array(test_images_nbr)
print(np.mean(test_images_nbr))
# Out:
# 3.0964825

# %%
# #Sanity check, view few images
image_number = random.randint(0, len(test_images)-1)
plt.figure(figsize=(12, 6))
plt.subplot(121)
plt.imshow(np.reshape((test_images[image_number, :, :, 2]), (256, 256, 1)))
plt.subplot(122)
plt.imshow(np.reshape(test_masks[image_number], (256, 256, 1)))
plt.show()
print(image_number)
# Out:
# 25

# %%
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate, Conv2DTranspose, BatchNormalization, Dropout, Activation, multiply
import tensorflow as tf
from tensorflow.keras import models, layers, regularizers
from tensorflow.keras import backend as K

def conv_block(x, filter_size, size, dropout, batch_norm=False):

    conv = layers.Conv2D(size, (filter_size, filter_size), padding="same")(x)
    if batch_norm is True:
        conv = layers.BatchNormalization(axis=3)(conv)
    conv = layers.Activation("relu")(conv)

    conv = layers.Conv2D(size, (filter_size, filter_size), padding="same")(conv)
    if batch_norm is True:
        conv = layers.BatchNormalization(axis=3)(conv)
    conv = layers.Activation("relu")(conv)

    if dropout > 0:
        conv = layers.Dropout(dropout)(conv)

    return conv


def repeat_elem(tensor, rep):


     return layers.Lambda(lambda x, repnum: K.repeat_elements(x, repnum, axis=3),
                          arguments={'repnum': rep})(tensor)

def gating_signal(input, out_size, batch_norm=False):

    x = layers.Conv2D(out_size, (1, 1), padding='same')(input)
    if batch_norm:
        x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    return x

def attention_block(x, gating, inter_shape):
    shape_x = K.int_shape(x)
    shape_g = K.int_shape(gating)

# Getting the x signal to the same shape as the gating signal
    theta_x = layers.Conv2D(inter_shape, (2, 2), strides=(2, 2), padding='same')(x)  # 16
    shape_theta_x = K.int_shape(theta_x)

# Getting the gating signal to the same number of filters as the inter_shape
    phi_g = layers.Conv2D(inter_shape, (1, 1), padding='same')(gating)
    upsample_g = layers.Conv2DTranspose(inter_shape, (3, 3),
                                 strides=(shape_theta_x[1] // shape_g[1], shape_theta_x[2] // shape_g[2]),
                                 padding='same')(phi_g)  # 16

    concat_xg = layers.add([upsample_g, theta_x])
    act_xg = layers.Activation('relu')(concat_xg)
    psi = layers.Conv2D(1, (1, 1), padding='same')(act_xg)
    sigmoid_xg = layers.Activation('sigmoid')(psi)
    shape_sigmoid = K.int_shape(sigmoid_xg)
    upsample_psi = layers.UpSampling2D(size=(shape_x[1] // shape_sigmoid[1], shape_x[2] // shape_sigmoid[2]))(sigmoid_xg)  # 32

    upsample_psi = repeat_elem(upsample_psi, shape_x[3])

    y = layers.multiply([upsample_psi, x])

    result = layers.Conv2D(shape_x[3], (1, 1), padding='same')(y)
    result_bn = layers.BatchNormalization()(result)
    return result_bn

def res_conv_block(x, filter_size, size, dropout, batch_norm=False):

    conv = layers.Conv2D(size, (filter_size, filter_size), padding='same')(x)
    if batch_norm is True:
        conv = layers.BatchNormalization(axis=3)(conv)
    conv = layers.Activation('relu')(conv)

    conv = layers.Conv2D(size, (filter_size, filter_size), padding='same')(conv)
    if batch_norm is True:
        conv = layers.BatchNormalization(axis=3)(conv)
    #conv = layers.Activation('relu')(conv)   
    if dropout > 0:
        conv = layers.Dropout(dropout)(conv)

    shortcut = layers.Conv2D(size, kernel_size=(1, 1), padding='same')(x)
    if batch_norm is True:
        shortcut = layers.BatchNormalization(axis=3)(shortcut)

    res_path = layers.add([shortcut, conv])
    res_path = layers.Activation('relu')(res_path)  
    return res_path

# %%
def Attention_UNet(input_shape, NUM_CLASSES=4, dropout_rate=0.0, batch_norm=True):

    # network structure
    FILTER_NUM = 16 # number of basic filters for the first layer
    FILTER_SIZE = 3 # size of the convolutional filter
    UP_SAMP_SIZE = 2 # size of upsampling filters

    input1 = layers.Input(input_shape)

    # Downsampling layers post
    # DownRes 1, convolution + pooling
    conv_128_1 = conv_block(input1, FILTER_SIZE, FILTER_NUM, dropout_rate, batch_norm)
    pool_64_1 = layers.MaxPooling2D(pool_size=(2,2))(conv_128_1)
    # DownRes 2
    conv_64_1 = conv_block(pool_64_1, FILTER_SIZE, 2*FILTER_NUM, dropout_rate, batch_norm)
    pool_32_1 = layers.MaxPooling2D(pool_size=(2,2))(conv_64_1)
    # DownRes 3
    conv_32_1 = conv_block(pool_32_1, FILTER_SIZE, 4*FILTER_NUM, dropout_rate, batch_norm)
    pool_16_1 = layers.MaxPooling2D(pool_size=(2,2))(conv_32_1)
    # DownRes 4
    conv_16_1 = conv_block(pool_16_1, FILTER_SIZE, 8*FILTER_NUM, dropout_rate, batch_norm)
    pool_8_1 = layers.MaxPooling2D(pool_size=(2,2))(conv_16_1)
    # DownRes 5, convolution only
    conv_8_1 = conv_block(pool_8_1, FILTER_SIZE, 16*FILTER_NUM, dropout_rate, batch_norm)

    # Downsampling layers pre
    input2 = layers.Input(input_shape)
    # DownRes 1, convolution + pooling
    conv_128_2 = conv_block(input2, FILTER_SIZE, FILTER_NUM, dropout_rate, batch_norm)
    pool_64_2 = layers.MaxPooling2D(pool_size=(2,2))(conv_128_2)
    # DownRes 2
    conv_64_2 = conv_block(pool_64_2, FILTER_SIZE, 2*FILTER_NUM, dropout_rate, batch_norm)
    pool_32_2 = layers.MaxPooling2D(pool_size=(2,2))(conv_64_2)
    # DownRes 3
    conv_32_2 = conv_block(pool_32_2, FILTER_SIZE, 4*FILTER_NUM, dropout_rate, batch_norm)
    pool_16_2 = layers.MaxPooling2D(pool_size=(2,2))(conv_32_2)
    # DownRes 4
    conv_16_2 = conv_block(pool_16_2, FILTER_SIZE, 8*FILTER_NUM, dropout_rate, batch_norm)
    pool_8_2 = layers.MaxPooling2D(pool_size=(2,2))(conv_16_2)
    # DownRes 5, convolution only
    conv_8_2 = conv_block(pool_8_2, FILTER_SIZE, 16*FILTER_NUM, dropout_rate, batch_norm)

    # Downsampling layers nbr
    input3 = layers.Input(input_shape)
    # DownRes 1, convolution + pooling
    conv_128_3 = conv_block(input2, FILTER_SIZE, FILTER_NUM, dropout_rate, batch_norm)
    pool_64_3 = layers.MaxPooling2D(pool_size=(2,2))(conv_128_3)
    # DownRes 2
    conv_64_3 = conv_block(pool_64_3, FILTER_SIZE, 2*FILTER_NUM, dropout_rate, batch_norm)
    pool_32_3 = layers.MaxPooling2D(pool_size=(2,2))(conv_64_3)
    # DownRes 3
    conv_32_3 = conv_block(pool_32_3, FILTER_SIZE, 4*FILTER_NUM, dropout_rate, batch_norm)
    pool_16_3 = layers.MaxPooling2D(pool_size=(2,2))(conv_32_3)
    # DownRes 4
    conv_16_3 = conv_block(pool_16_3, FILTER_SIZE, 8*FILTER_NUM, dropout_rate, batch_norm)
    pool_8_3 = layers.MaxPooling2D(pool_size=(2,2))(conv_16_3)
    # DownRes 5, convolution only
    conv_8_3 = conv_block(pool_8_3, FILTER_SIZE, 16*FILTER_NUM, dropout_rate, batch_norm)

    x8 = concatenate([conv_8_1, conv_8_2, conv_8_3])
    x16 = concatenate([conv_16_1, conv_16_2, conv_16_3])
    x32 = concatenate([conv_32_1, conv_32_2, conv_32_3])
    x64 = concatenate([conv_64_1, conv_64_2, conv_64_3])
    x128 = concatenate([conv_128_1, conv_128_2, conv_128_3])

    # Upsampling layers
    # UpRes 6, attention gated concatenation + upsampling + double residual convolution
    gating_16 = gating_signal(x8, 8*FILTER_NUM, batch_norm)
    att_16 = attention_block(x16, gating_16, 8*FILTER_NUM)
    up_16 = layers.UpSampling2D(size=(UP_SAMP_SIZE, UP_SAMP_SIZE), data_format="channels_last")(x8)
    up_16 = layers.concatenate([up_16, att_16], axis=3)
    up_conv_16 = conv_block(up_16, FILTER_SIZE, 8*FILTER_NUM, dropout_rate, batch_norm)
    # UpRes 7
    gating_32 = gating_signal(up_conv_16, 4*FILTER_NUM, batch_norm)
    att_32 = attention_block(x32, gating_32, 4*FILTER_NUM)
    up_32 = layers.UpSampling2D(size=(UP_SAMP_SIZE, UP_SAMP_SIZE), data_format="channels_last")(up_conv_16)
    up_32 = layers.concatenate([up_32, att_32], axis=3)
    up_conv_32 = conv_block(up_32, FILTER_SIZE, 4*FILTER_NUM, dropout_rate, batch_norm)
    # UpRes 8
    gating_64 = gating_signal(up_conv_32, 2*FILTER_NUM, batch_norm)
    att_64 = attention_block(x64, gating_64, 2*FILTER_NUM)
    up_64 = layers.UpSampling2D(size=(UP_SAMP_SIZE, UP_SAMP_SIZE), data_format="channels_last")(up_conv_32)
    up_64 = layers.concatenate([up_64, att_64], axis=3)
    up_conv_64 = conv_block(up_64, FILTER_SIZE, 2*FILTER_NUM, dropout_rate, batch_norm)
    # UpRes 9
    gating_128 = gating_signal(up_conv_64, FILTER_NUM, batch_norm)
    att_128 = attention_block(x128, gating_128, FILTER_NUM)
    up_128 = layers.UpSampling2D(size=(UP_SAMP_SIZE, UP_SAMP_SIZE), data_format="channels_last")(up_conv_64)
    up_128 = layers.concatenate([up_128, att_128], axis=3)
    up_conv_128 = conv_block(up_128, FILTER_SIZE, FILTER_NUM, dropout_rate, batch_norm)

    # 1*1 convolutional layers
    conv_final = layers.Conv2D(NUM_CLASSES, kernel_size=(1,1))(up_conv_128)
    conv_final = layers.BatchNormalization(axis=3)(conv_final)
    conv_final = layers.Activation('softmax')(conv_final)  #Change to softmax for multichannel

    # Model integration
    model = models.Model(inputs=[input1, input2, input3], outputs=[conv_final], name="Attention_UNet")
    return model

# %%
def Attention_ResUNet(input_shape, NUM_CLASSES=4, dropout_rate=0.2, batch_norm=True):

    # network structure
    FILTER_NUM = 16 # number of basic filters for the first layer
    FILTER_SIZE = 3 # size of the convolutional filter
    UP_SAMP_SIZE = 2 # size of upsampling filters

    input1 = layers.Input(input_shape)

    # Downsampling layers post
    # DownRes 1, convolution + pooling
    conv_128_1 = res_conv_block(input1, FILTER_SIZE, FILTER_NUM, dropout_rate, batch_norm)
    pool_64_1 = layers.MaxPooling2D(pool_size=(2,2))(conv_128_1)
    # DownRes 2
    conv_64_1 = res_conv_block(pool_64_1, FILTER_SIZE, 2*FILTER_NUM, dropout_rate, batch_norm)
    pool_32_1 = layers.MaxPooling2D(pool_size=(2,2))(conv_64_1)
    # DownRes 3
    conv_32_1 = res_conv_block(pool_32_1, FILTER_SIZE, 4*FILTER_NUM, dropout_rate, batch_norm)
    pool_16_1 = layers.MaxPooling2D(pool_size=(2,2))(conv_32_1)
    # DownRes 4
    conv_16_1 = res_conv_block(pool_16_1, FILTER_SIZE, 8*FILTER_NUM, dropout_rate, batch_norm)
    pool_8_1 = layers.MaxPooling2D(pool_size=(2,2))(conv_16_1)
    # DownRes 5, convolution only
    conv_8_1 = res_conv_block(pool_8_1, FILTER_SIZE, 16*FILTER_NUM, dropout_rate, batch_norm)

    # Downsampling layers pre
    input2 = layers.Input(input_shape)
    # DownRes 1, convolution + pooling
    conv_128_2 = res_conv_block(input2, FILTER_SIZE, FILTER_NUM, dropout_rate, batch_norm)
    pool_64_2 = layers.MaxPooling2D(pool_size=(2,2))(conv_128_2)
    # DownRes 2
    conv_64_2 = res_conv_block(pool_64_2, FILTER_SIZE, 2*FILTER_NUM, dropout_rate, batch_norm)
    pool_32_2 = layers.MaxPooling2D(pool_size=(2,2))(conv_64_2)
    # DownRes 3
    conv_32_2 = res_conv_block(pool_32_2, FILTER_SIZE, 4*FILTER_NUM, dropout_rate, batch_norm)
    pool_16_2 = layers.MaxPooling2D(pool_size=(2,2))(conv_32_2)
    # DownRes 4
    conv_16_2 = res_conv_block(pool_16_2, FILTER_SIZE, 8*FILTER_NUM, dropout_rate, batch_norm)
    pool_8_2 = layers.MaxPooling2D(pool_size=(2,2))(conv_16_2)
    # DownRes 5, convolution only
    conv_8_2 = res_conv_block(pool_8_2, FILTER_SIZE, 16*FILTER_NUM, dropout_rate, batch_norm)

    # Downsampling layers nbr
    input3 = layers.Input(input_shape)
    # DownRes 1, convolution + pooling
    conv_128_3 = res_conv_block(input2, FILTER_SIZE, FILTER_NUM, dropout_rate, batch_norm)
    pool_64_3 = layers.MaxPooling2D(pool_size=(2,2))(conv_128_3)
    # DownRes 2
    conv_64_3 = res_conv_block(pool_64_3, FILTER_SIZE, 2*FILTER_NUM, dropout_rate, batch_norm)
    pool_32_3 = layers.MaxPooling2D(pool_size=(2,2))(conv_64_3)
    # DownRes 3
    conv_32_3 = res_conv_block(pool_32_3, FILTER_SIZE, 4*FILTER_NUM, dropout_rate, batch_norm)
    pool_16_3 = layers.MaxPooling2D(pool_size=(2,2))(conv_32_3)
    # DownRes 4
    conv_16_3 = res_conv_block(pool_16_3, FILTER_SIZE, 8*FILTER_NUM, dropout_rate, batch_norm)
    pool_8_3 = layers.MaxPooling2D(pool_size=(2,2))(conv_16_3)
    # DownRes 5, convolution only
    conv_8_3 = res_conv_block(pool_8_3, FILTER_SIZE, 16*FILTER_NUM, dropout_rate, batch_norm)

    x8 = concatenate([conv_8_1, conv_8_2, conv_8_3])
    x16 = concatenate([conv_16_1, conv_16_2, conv_16_3])
    x32 = concatenate([conv_32_1, conv_32_2, conv_32_3])
    x64 = concatenate([conv_64_1, conv_64_2, conv_64_3])
    x128 = concatenate([conv_128_1, conv_128_2, conv_128_3])

    # Upsampling layers
    # UpRes 6, attention gated concatenation + upsampling + double residual convolution
    gating_16 = gating_signal(x8, 8*FILTER_NUM, batch_norm)
    att_16 = attention_block(x16, gating_16, 8*FILTER_NUM)
    up_16 = layers.UpSampling2D(size=(UP_SAMP_SIZE, UP_SAMP_SIZE), data_format="channels_last")(x8)
    up_16 = layers.concatenate([up_16, att_16], axis=3)
    up_conv_16 = res_conv_block(up_16, FILTER_SIZE, 8*FILTER_NUM, dropout_rate, batch_norm)
    # UpRes 7
    gating_32 = gating_signal(up_conv_16, 4*FILTER_NUM, batch_norm)
    att_32 = attention_block(x32, gating_32, 4*FILTER_NUM)
    up_32 = layers.UpSampling2D(size=(UP_SAMP_SIZE, UP_SAMP_SIZE), data_format="channels_last")(up_conv_16)
    up_32 = layers.concatenate([up_32, att_32], axis=3)
    up_conv_32 = res_conv_block(up_32, FILTER_SIZE, 4*FILTER_NUM, dropout_rate, batch_norm)
    # UpRes 8
    gating_64 = gating_signal(up_conv_32, 2*FILTER_NUM, batch_norm)
    att_64 = attention_block(x64, gating_64, 2*FILTER_NUM)
    up_64 = layers.UpSampling2D(size=(UP_SAMP_SIZE, UP_SAMP_SIZE), data_format="channels_last")(up_conv_32)
    up_64 = layers.concatenate([up_64, att_64], axis=3)
    up_conv_64 = res_conv_block(up_64, FILTER_SIZE, 2*FILTER_NUM, dropout_rate, batch_norm)
    # UpRes 9
    gating_128 = gating_signal(up_conv_64, FILTER_NUM, batch_norm)
    att_128 = attention_block(x128, gating_128, FILTER_NUM)
    up_128 = layers.UpSampling2D(size=(UP_SAMP_SIZE, UP_SAMP_SIZE), data_format="channels_last")(up_conv_64)
    up_128 = layers.concatenate([up_128, att_128], axis=3)
    up_conv_128 = res_conv_block(up_128, FILTER_SIZE, FILTER_NUM, dropout_rate, batch_norm)

    # 1*1 convolutional layers
    conv_final = layers.Conv2D(NUM_CLASSES, kernel_size=(1,1))(up_conv_128)
    conv_final = layers.BatchNormalization(axis=3)(conv_final)
    conv_final = layers.Activation('softmax')(conv_final)  #Change to softmax for multichannel

    # Model integration
    model = models.Model(inputs=[input1, input2, input3], outputs=[conv_final], name="Attention_ResUNet")
    print(model.summary())
    return model

# %%
import tensorflow as tf
from keras import backend as K

def categorical_mean_iou_loss(y_true, y_pred):
    y_true = tf.cast(y_true, y_pred.dtype)  

    # Calculate intersection and union
    intersection = K.sum(K.abs(y_true * y_pred), axis=[1, 2])
    union = K.sum(y_true, axis=[1, 2]) + K.sum(y_pred, axis=[1, 2]) - intersection

    # Calculate mean IoU loss
    iou = (intersection + K.epsilon()) / (union + K.epsilon())
    mean_iou_loss = 1 - K.mean(iou)

    return mean_iou_loss

# %%
class MyMeanIOU(tf.keras.metrics.MeanIoU):
    def update_state(self, y_true, y_pred, sample_weight=None):
        return super().update_state(tf.argmax(y_true, axis=-1), tf.argmax(y_pred, axis=-1), sample_weight)

# %%
# training
def get_model():
    return Attention_ResUNet((256, 256, 3))
model = get_model()
model.compile(optimizer = 'adam', loss=categorical_mean_iou_loss, metrics = [MyMeanIOU(4)])
# tf.keras.losses.CategoricalCrossentropy()
# categorical_focal_loss(gamma=2.0, alpha=0.25)

# %%
model.summary()

# %%
from keras_flops import get_flops
# Calculae FLOPS
flops = get_flops(model, batch_size=1)
print(f"FLOPS: {flops / 10 ** 9:.03} G")
print(flops)

# %%
train_list = [X_train, train_images_pre, train_images_nbr]
test_list = [test_images, test_images_pre, test_images_nbr]

# %%
from tensorflow.keras.models import load_model

model_path =r"C:\Users\urielm\Documents\GitHub\Wildfire-Burn-Severity-Assessment\Model\ra_unet_nbr.h5"

try:
    model = load_model(model_path)
    print("✅ El archivo .h5 contiene la arquitectura y pesos.")
except:
    print("❌ El archivo .h5 solo contiene los pesos. Debes definir la arquitectura antes de cargarlos.")
# Out:
# ❌ El archivo .h5 solo contiene los pesos. Debes definir la arquitectura antes de cargarlos.

# %%
# ✅ Cargar la arquitectura del modelo y los pesos entrenados
model = Attention_ResUNet((256, 256, 3), NUM_CLASSES=4)
model.load_weights(model_path)

print("✅ Modelo cargado correctamente.")
# Out:
# Model: "Attention_ResUNet"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_7 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  input_8 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d_156 (Conv2D)            (None, 256, 256, 16  448         ['input_7[0][0]']
#                                 )
#
#  conv2d_171 (Conv2D)            (None, 256, 256, 16  448         ['input_8[0][0]']
#                                 )
#
#  conv2d_186 (Conv2D)            (None, 256, 256, 16  448         ['input_8[0][0]']
#                                 )
#
#  batch_normalization_132 (Batch  (None, 256, 256, 16  64         ['conv2d_156[0][0]']
#  Normalization)                 )
#
#  batch_normalization_147 (Batch  (None, 256, 256, 16  64         ['conv2d_171[0][0]']
#  Normalization)                 )
#
#  batch_normalization_162 (Batch  (None, 256, 256, 16  64         ['conv2d_186[0][0]']
#  Normalization)                 )
#
#  activation_102 (Activation)    (None, 256, 256, 16  0           ['batch_normalization_132[0][0]']
#                                 )
#
#  activation_112 (Activation)    (None, 256, 256, 16  0           ['batch_normalization_147[0][0]']
#                                 )
#
#  activation_122 (Activation)    (None, 256, 256, 16  0           ['batch_normalization_162[0][0]']
#                                 )
#
#  conv2d_157 (Conv2D)            (None, 256, 256, 16  2320        ['activation_102[0][0]']
#                                 )
#
#  conv2d_172 (Conv2D)            (None, 256, 256, 16  2320        ['activation_112[0][0]']
#                                 )
#
#  conv2d_187 (Conv2D)            (None, 256, 256, 16  2320        ['activation_122[0][0]']
#                                 )
#
#  conv2d_158 (Conv2D)            (None, 256, 256, 16  64          ['input_7[0][0]']
#                                 )
#
#  batch_normalization_133 (Batch  (None, 256, 256, 16  64         ['conv2d_157[0][0]']
#  Normalization)                 )
#
#  conv2d_173 (Conv2D)            (None, 256, 256, 16  64          ['input_8[0][0]']
#                                 )
#
#  batch_normalization_148 (Batch  (None, 256, 256, 16  64         ['conv2d_172[0][0]']
#  Normalization)                 )
#
#  conv2d_188 (Conv2D)            (None, 256, 256, 16  64          ['input_8[0][0]']
#                                 )
#
#  batch_normalization_163 (Batch  (None, 256, 256, 16  64         ['conv2d_187[0][0]']
#  Normalization)                 )
#
#  batch_normalization_134 (Batch  (None, 256, 256, 16  64         ['conv2d_158[0][0]']
#  Normalization)                 )
#
#  dropout_38 (Dropout)           (None, 256, 256, 16  0           ['batch_normalization_133[0][0]']
#                                 )
#
#  batch_normalization_149 (Batch  (None, 256, 256, 16  64         ['conv2d_173[0][0]']
#  Normalization)                 )
#
#  dropout_43 (Dropout)           (None, 256, 256, 16  0           ['batch_normalization_148[0][0]']
#                                 )
#
#  batch_normalization_164 (Batch  (None, 256, 256, 16  64         ['conv2d_188[0][0]']
#  Normalization)                 )
#
#  dropout_48 (Dropout)           (None, 256, 256, 16  0           ['batch_normalization_163[0][0]']
#                                 )
#
#  add_46 (Add)                   (None, 256, 256, 16  0           ['batch_normalization_134[0][0]',
#                                 )                                 'dropout_38[0][0]']
#
#  add_51 (Add)                   (None, 256, 256, 16  0           ['batch_normalization_149[0][0]',
#                                 )                                 'dropout_43[0][0]']
#
#  add_56 (Add)                   (None, 256, 256, 16  0           ['batch_normalization_164[0][0]',
#                                 )                                 'dropout_48[0][0]']
#
#  activation_103 (Activation)    (None, 256, 256, 16  0           ['add_46[0][0]']
#                                 )
#
#  activation_113 (Activation)    (None, 256, 256, 16  0           ['add_51[0][0]']
#                                 )
#
#  activation_123 (Activation)    (None, 256, 256, 16  0           ['add_56[0][0]']
#                                 )
#
#  max_pooling2d_24 (MaxPooling2D  (None, 128, 128, 16  0          ['activation_103[0][0]']
#  )                              )
#
#  max_pooling2d_28 (MaxPooling2D  (None, 128, 128, 16  0          ['activation_113[0][0]']
#  )                              )
#
#  max_pooling2d_32 (MaxPooling2D  (None, 128, 128, 16  0          ['activation_123[0][0]']
#  )                              )
#
#  conv2d_159 (Conv2D)            (None, 128, 128, 32  4640        ['max_pooling2d_24[0][0]']
#                                 )
#
#  conv2d_174 (Conv2D)            (None, 128, 128, 32  4640        ['max_pooling2d_28[0][0]']
#                                 )
#
#  conv2d_189 (Conv2D)            (None, 128, 128, 32  4640        ['max_pooling2d_32[0][0]']
#                                 )
#
#  batch_normalization_135 (Batch  (None, 128, 128, 32  128        ['conv2d_159[0][0]']
#  Normalization)                 )
#
#  batch_normalization_150 (Batch  (None, 128, 128, 32  128        ['conv2d_174[0][0]']
#  Normalization)                 )
#
#  batch_normalization_165 (Batch  (None, 128, 128, 32  128        ['conv2d_189[0][0]']
#  Normalization)                 )
#
#  activation_104 (Activation)    (None, 128, 128, 32  0           ['batch_normalization_135[0][0]']
#                                 )
#
#  activation_114 (Activation)    (None, 128, 128, 32  0           ['batch_normalization_150[0][0]']
#                                 )
#
#  activation_124 (Activation)    (None, 128, 128, 32  0           ['batch_normalization_165[0][0]']
#                                 )
#
#  conv2d_160 (Conv2D)            (None, 128, 128, 32  9248        ['activation_104[0][0]']
#                                 )
#
#  conv2d_175 (Conv2D)            (None, 128, 128, 32  9248        ['activation_114[0][0]']
#                                 )
#
#  conv2d_190 (Conv2D)            (None, 128, 128, 32  9248        ['activation_124[0][0]']
#                                 )
#
#  conv2d_161 (Conv2D)            (None, 128, 128, 32  544         ['max_pooling2d_24[0][0]']
#                                 )
#
#  batch_normalization_136 (Batch  (None, 128, 128, 32  128        ['conv2d_160[0][0]']
#  Normalization)                 )
#
#  conv2d_176 (Conv2D)            (None, 128, 128, 32  544         ['max_pooling2d_28[0][0]']
#                                 )
#
#  batch_normalization_151 (Batch  (None, 128, 128, 32  128        ['conv2d_175[0][0]']
#  Normalization)                 )
#
#  conv2d_191 (Conv2D)            (None, 128, 128, 32  544         ['max_pooling2d_32[0][0]']
#                                 )
#
#  batch_normalization_166 (Batch  (None, 128, 128, 32  128        ['conv2d_190[0][0]']
#  Normalization)                 )
#
#  batch_normalization_137 (Batch  (None, 128, 128, 32  128        ['conv2d_161[0][0]']
#  Normalization)                 )
#
#  dropout_39 (Dropout)           (None, 128, 128, 32  0           ['batch_normalization_136[0][0]']
#                                 )
#
#  batch_normalization_152 (Batch  (None, 128, 128, 32  128        ['conv2d_176[0][0]']
#  Normalization)                 )
#
#  dropout_44 (Dropout)           (None, 128, 128, 32  0           ['batch_normalization_151[0][0]']
#                                 )
#
#  batch_normalization_167 (Batch  (None, 128, 128, 32  128        ['conv2d_191[0][0]']
#  Normalization)                 )
#
#  dropout_49 (Dropout)           (None, 128, 128, 32  0           ['batch_normalization_166[0][0]']
#                                 )
#
#  add_47 (Add)                   (None, 128, 128, 32  0           ['batch_normalization_137[0][0]',
#                                 )                                 'dropout_39[0][0]']
#
#  add_52 (Add)                   (None, 128, 128, 32  0           ['batch_normalization_152[0][0]',
#                                 )                                 'dropout_44[0][0]']
#
#  add_57 (Add)                   (None, 128, 128, 32  0           ['batch_normalization_167[0][0]',
#                                 )                                 'dropout_49[0][0]']
#
#  activation_105 (Activation)    (None, 128, 128, 32  0           ['add_47[0][0]']
#                                 )
#
#  activation_115 (Activation)    (None, 128, 128, 32  0           ['add_52[0][0]']
#                                 )
#
#  activation_125 (Activation)    (None, 128, 128, 32  0           ['add_57[0][0]']
#                                 )
#
#  max_pooling2d_25 (MaxPooling2D  (None, 64, 64, 32)  0           ['activation_105[0][0]']
#  )
#
#  max_pooling2d_29 (MaxPooling2D  (None, 64, 64, 32)  0           ['activation_115[0][0]']
#  )
#
#  max_pooling2d_33 (MaxPooling2D  (None, 64, 64, 32)  0           ['activation_125[0][0]']
#  )
#
#  conv2d_162 (Conv2D)            (None, 64, 64, 64)   18496       ['max_pooling2d_25[0][0]']
#
#  conv2d_177 (Conv2D)            (None, 64, 64, 64)   18496       ['max_pooling2d_29[0][0]']
#
#  conv2d_192 (Conv2D)            (None, 64, 64, 64)   18496       ['max_pooling2d_33[0][0]']
#
#  batch_normalization_138 (Batch  (None, 64, 64, 64)  256         ['conv2d_162[0][0]']
#  Normalization)
#
#  batch_normalization_153 (Batch  (None, 64, 64, 64)  256         ['conv2d_177[0][0]']
#  Normalization)
#
#  batch_normalization_168 (Batch  (None, 64, 64, 64)  256         ['conv2d_192[0][0]']
#  Normalization)
#
#  activation_106 (Activation)    (None, 64, 64, 64)   0           ['batch_normalization_138[0][0]']
#
#  activation_116 (Activation)    (None, 64, 64, 64)   0           ['batch_normalization_153[0][0]']
#
#  activation_126 (Activation)    (None, 64, 64, 64)   0           ['batch_normalization_168[0][0]']
#
#  conv2d_163 (Conv2D)            (None, 64, 64, 64)   36928       ['activation_106[0][0]']
#
#  conv2d_178 (Conv2D)            (None, 64, 64, 64)   36928       ['activation_116[0][0]']
#
#  conv2d_193 (Conv2D)            (None, 64, 64, 64)   36928       ['activation_126[0][0]']
#
#  conv2d_164 (Conv2D)            (None, 64, 64, 64)   2112        ['max_pooling2d_25[0][0]']
#
#  batch_normalization_139 (Batch  (None, 64, 64, 64)  256         ['conv2d_163[0][0]']
#  Normalization)
#
#  conv2d_179 (Conv2D)            (None, 64, 64, 64)   2112        ['max_pooling2d_29[0][0]']
#
#  batch_normalization_154 (Batch  (None, 64, 64, 64)  256         ['conv2d_178[0][0]']
#  Normalization)
#
#  conv2d_194 (Conv2D)            (None, 64, 64, 64)   2112        ['max_pooling2d_33[0][0]']
#
#  batch_normalization_169 (Batch  (None, 64, 64, 64)  256         ['conv2d_193[0][0]']
#  Normalization)
#
#  batch_normalization_140 (Batch  (None, 64, 64, 64)  256         ['conv2d_164[0][0]']
#  Normalization)
#
#  dropout_40 (Dropout)           (None, 64, 64, 64)   0           ['batch_normalization_139[0][0]']
#
#  batch_normalization_155 (Batch  (None, 64, 64, 64)  256         ['conv2d_179[0][0]']
#  Normalization)
#
#  dropout_45 (Dropout)           (None, 64, 64, 64)   0           ['batch_normalization_154[0][0]']
#
#  batch_normalization_170 (Batch  (None, 64, 64, 64)  256         ['conv2d_194[0][0]']
#  Normalization)
#
#  dropout_50 (Dropout)           (None, 64, 64, 64)   0           ['batch_normalization_169[0][0]']
#
#  add_48 (Add)                   (None, 64, 64, 64)   0           ['batch_normalization_140[0][0]',
#                                                                   'dropout_40[0][0]']
#
#  add_53 (Add)                   (None, 64, 64, 64)   0           ['batch_normalization_155[0][0]',
#                                                                   'dropout_45[0][0]']
#
#  add_58 (Add)                   (None, 64, 64, 64)   0           ['batch_normalization_170[0][0]',
#                                                                   'dropout_50[0][0]']
#
#  activation_107 (Activation)    (None, 64, 64, 64)   0           ['add_48[0][0]']
#
#  activation_117 (Activation)    (None, 64, 64, 64)   0           ['add_53[0][0]']
#
#  activation_127 (Activation)    (None, 64, 64, 64)   0           ['add_58[0][0]']
#
#  max_pooling2d_26 (MaxPooling2D  (None, 32, 32, 64)  0           ['activation_107[0][0]']
#  )
#
#  max_pooling2d_30 (MaxPooling2D  (None, 32, 32, 64)  0           ['activation_117[0][0]']
#  )
#
#  max_pooling2d_34 (MaxPooling2D  (None, 32, 32, 64)  0           ['activation_127[0][0]']
#  )
#
#  conv2d_165 (Conv2D)            (None, 32, 32, 128)  73856       ['max_pooling2d_26[0][0]']
#
#  conv2d_180 (Conv2D)            (None, 32, 32, 128)  73856       ['max_pooling2d_30[0][0]']
#
#  conv2d_195 (Conv2D)            (None, 32, 32, 128)  73856       ['max_pooling2d_34[0][0]']
#
#  batch_normalization_141 (Batch  (None, 32, 32, 128)  512        ['conv2d_165[0][0]']
#  Normalization)
#
#  batch_normalization_156 (Batch  (None, 32, 32, 128)  512        ['conv2d_180[0][0]']
#  Normalization)
#
#  batch_normalization_171 (Batch  (None, 32, 32, 128)  512        ['conv2d_195[0][0]']
#  Normalization)
#
#  activation_108 (Activation)    (None, 32, 32, 128)  0           ['batch_normalization_141[0][0]']
#
#  activation_118 (Activation)    (None, 32, 32, 128)  0           ['batch_normalization_156[0][0]']
#
#  activation_128 (Activation)    (None, 32, 32, 128)  0           ['batch_normalization_171[0][0]']
#
#  conv2d_166 (Conv2D)            (None, 32, 32, 128)  147584      ['activation_108[0][0]']
#
#  conv2d_181 (Conv2D)            (None, 32, 32, 128)  147584      ['activation_118[0][0]']
#
#  conv2d_196 (Conv2D)            (None, 32, 32, 128)  147584      ['activation_128[0][0]']
#
#  conv2d_167 (Conv2D)            (None, 32, 32, 128)  8320        ['max_pooling2d_26[0][0]']
#
#  batch_normalization_142 (Batch  (None, 32, 32, 128)  512        ['conv2d_166[0][0]']
#  Normalization)
#
#  conv2d_182 (Conv2D)            (None, 32, 32, 128)  8320        ['max_pooling2d_30[0][0]']
#
#  batch_normalization_157 (Batch  (None, 32, 32, 128)  512        ['conv2d_181[0][0]']
#  Normalization)
#
#  conv2d_197 (Conv2D)            (None, 32, 32, 128)  8320        ['max_pooling2d_34[0][0]']
#
#  batch_normalization_172 (Batch  (None, 32, 32, 128)  512        ['conv2d_196[0][0]']
#  Normalization)
#
#  batch_normalization_143 (Batch  (None, 32, 32, 128)  512        ['conv2d_167[0][0]']
#  Normalization)
#
#  dropout_41 (Dropout)           (None, 32, 32, 128)  0           ['batch_normalization_142[0][0]']
#
#  batch_normalization_158 (Batch  (None, 32, 32, 128)  512        ['conv2d_182[0][0]']
#  Normalization)
#
#  dropout_46 (Dropout)           (None, 32, 32, 128)  0           ['batch_normalization_157[0][0]']
#
#  batch_normalization_173 (Batch  (None, 32, 32, 128)  512        ['conv2d_197[0][0]']
#  Normalization)
#
#  dropout_51 (Dropout)           (None, 32, 32, 128)  0           ['batch_normalization_172[0][0]']
#
#  add_49 (Add)                   (None, 32, 32, 128)  0           ['batch_normalization_143[0][0]',
#                                                                   'dropout_41[0][0]']
#
#  add_54 (Add)                   (None, 32, 32, 128)  0           ['batch_normalization_158[0][0]',
#                                                                   'dropout_46[0][0]']
#
#  add_59 (Add)                   (None, 32, 32, 128)  0           ['batch_normalization_173[0][0]',
#                                                                   'dropout_51[0][0]']
#
#  activation_109 (Activation)    (None, 32, 32, 128)  0           ['add_49[0][0]']
#
#  activation_119 (Activation)    (None, 32, 32, 128)  0           ['add_54[0][0]']
#
#  activation_129 (Activation)    (None, 32, 32, 128)  0           ['add_59[0][0]']
#
#  max_pooling2d_27 (MaxPooling2D  (None, 16, 16, 128)  0          ['activation_109[0][0]']
#  )
#
#  max_pooling2d_31 (MaxPooling2D  (None, 16, 16, 128)  0          ['activation_119[0][0]']
#  )
#
#  max_pooling2d_35 (MaxPooling2D  (None, 16, 16, 128)  0          ['activation_129[0][0]']
#  )
#
#  conv2d_168 (Conv2D)            (None, 16, 16, 256)  295168      ['max_pooling2d_27[0][0]']
#
#  conv2d_183 (Conv2D)            (None, 16, 16, 256)  295168      ['max_pooling2d_31[0][0]']
#
#  conv2d_198 (Conv2D)            (None, 16, 16, 256)  295168      ['max_pooling2d_35[0][0]']
#
#  batch_normalization_144 (Batch  (None, 16, 16, 256)  1024       ['conv2d_168[0][0]']
#  Normalization)
#
#  batch_normalization_159 (Batch  (None, 16, 16, 256)  1024       ['conv2d_183[0][0]']
#  Normalization)
#
#  batch_normalization_174 (Batch  (None, 16, 16, 256)  1024       ['conv2d_198[0][0]']
#  Normalization)
#
#  activation_110 (Activation)    (None, 16, 16, 256)  0           ['batch_normalization_144[0][0]']
#
#  activation_120 (Activation)    (None, 16, 16, 256)  0           ['batch_normalization_159[0][0]']
#
#  activation_130 (Activation)    (None, 16, 16, 256)  0           ['batch_normalization_174[0][0]']
#
#  conv2d_169 (Conv2D)            (None, 16, 16, 256)  590080      ['activation_110[0][0]']
#
#  conv2d_184 (Conv2D)            (None, 16, 16, 256)  590080      ['activation_120[0][0]']
#
#  conv2d_199 (Conv2D)            (None, 16, 16, 256)  590080      ['activation_130[0][0]']
#
#  conv2d_170 (Conv2D)            (None, 16, 16, 256)  33024       ['max_pooling2d_27[0][0]']
#
#  batch_normalization_145 (Batch  (None, 16, 16, 256)  1024       ['conv2d_169[0][0]']
#  Normalization)
#
#  conv2d_185 (Conv2D)            (None, 16, 16, 256)  33024       ['max_pooling2d_31[0][0]']
#
#  batch_normalization_160 (Batch  (None, 16, 16, 256)  1024       ['conv2d_184[0][0]']
#  Normalization)
#
#  conv2d_200 (Conv2D)            (None, 16, 16, 256)  33024       ['max_pooling2d_35[0][0]']
#
#  batch_normalization_175 (Batch  (None, 16, 16, 256)  1024       ['conv2d_199[0][0]']
#  Normalization)
#
#  batch_normalization_146 (Batch  (None, 16, 16, 256)  1024       ['conv2d_170[0][0]']
#  Normalization)
#
#  dropout_42 (Dropout)           (None, 16, 16, 256)  0           ['batch_normalization_145[0][0]']
#
#  batch_normalization_161 (Batch  (None, 16, 16, 256)  1024       ['conv2d_185[0][0]']
#  Normalization)
#
#  dropout_47 (Dropout)           (None, 16, 16, 256)  0           ['batch_normalization_160[0][0]']
#
#  batch_normalization_176 (Batch  (None, 16, 16, 256)  1024       ['conv2d_200[0][0]']
#  Normalization)
#
#  dropout_52 (Dropout)           (None, 16, 16, 256)  0           ['batch_normalization_175[0][0]']
#
#  add_50 (Add)                   (None, 16, 16, 256)  0           ['batch_normalization_146[0][0]',
#                                                                   'dropout_42[0][0]']
#
#  add_55 (Add)                   (None, 16, 16, 256)  0           ['batch_normalization_161[0][0]',
#                                                                   'dropout_47[0][0]']
#
#  add_60 (Add)                   (None, 16, 16, 256)  0           ['batch_normalization_176[0][0]',
#                                                                   'dropout_52[0][0]']
#
#  activation_111 (Activation)    (None, 16, 16, 256)  0           ['add_50[0][0]']
#
#  activation_121 (Activation)    (None, 16, 16, 256)  0           ['add_55[0][0]']
#
#  activation_131 (Activation)    (None, 16, 16, 256)  0           ['add_60[0][0]']
#
#  concatenate_18 (Concatenate)   (None, 16, 16, 768)  0           ['activation_111[0][0]',
#                                                                   'activation_121[0][0]',
#                                                                   'activation_131[0][0]']
#
#  conv2d_201 (Conv2D)            (None, 16, 16, 128)  98432       ['concatenate_18[0][0]']
#
#  batch_normalization_177 (Batch  (None, 16, 16, 128)  512        ['conv2d_201[0][0]']
#  Normalization)
#
#  activation_132 (Activation)    (None, 16, 16, 128)  0           ['batch_normalization_177[0][0]']
#
#  conv2d_203 (Conv2D)            (None, 16, 16, 128)  16512       ['activation_132[0][0]']
#
#  concatenate_19 (Concatenate)   (None, 32, 32, 384)  0           ['activation_109[0][0]',
#                                                                   'activation_119[0][0]',
#                                                                   'activation_129[0][0]']
#
#  conv2d_transpose_8 (Conv2DTran  (None, 16, 16, 128)  147584     ['conv2d_203[0][0]']
#  spose)
#
#  conv2d_202 (Conv2D)            (None, 16, 16, 128)  196736      ['concatenate_19[0][0]']
#
#  add_61 (Add)                   (None, 16, 16, 128)  0           ['conv2d_transpose_8[0][0]',
#                                                                   'conv2d_202[0][0]']
#
#  activation_133 (Activation)    (None, 16, 16, 128)  0           ['add_61[0][0]']
#
#  conv2d_204 (Conv2D)            (None, 16, 16, 1)    129         ['activation_133[0][0]']
#
#  activation_134 (Activation)    (None, 16, 16, 1)    0           ['conv2d_204[0][0]']
#
#  up_sampling2d_16 (UpSampling2D  (None, 32, 32, 1)   0           ['activation_134[0][0]']
#  )
#
#  lambda_8 (Lambda)              (None, 32, 32, 384)  0           ['up_sampling2d_16[0][0]']
#
#  multiply_8 (Multiply)          (None, 32, 32, 384)  0           ['lambda_8[0][0]',
#                                                                   'concatenate_19[0][0]']
#
#  conv2d_205 (Conv2D)            (None, 32, 32, 384)  147840      ['multiply_8[0][0]']
#
#  up_sampling2d_17 (UpSampling2D  (None, 32, 32, 768)  0          ['concatenate_18[0][0]']
#  )
# ...
#  conv2d_transpose_10 (Conv2DTra  (None, 64, 64, 32)  9248        ['conv2d_219[0][0]']
#  nspose)
#
#  conv2d_218 (Conv2D)            (None, 64, 64, 32)   12320       ['concatenate_21[0][0]']
#
#  add_65 (Add)                   (None, 64, 64, 32)   0           ['conv2d_transpose_10[0][0]',
#                                                                   'conv2d_218[0][0]']
#
#  activation_143 (Activation)    (None, 64, 64, 32)   0           ['add_65[0][0]']
#
#  conv2d_220 (Conv2D)            (None, 64, 64, 1)    33          ['activation_143[0][0]']
#
#  activation_144 (Activation)    (None, 64, 64, 1)    0           ['conv2d_220[0][0]']
#
#  up_sampling2d_20 (UpSampling2D  (None, 128, 128, 1)  0          ['activation_144[0][0]']
#  )
#
#  lambda_10 (Lambda)             (None, 128, 128, 96  0           ['up_sampling2d_20[0][0]']
#                                 )
#
#  multiply_10 (Multiply)         (None, 128, 128, 96  0           ['lambda_10[0][0]',
#                                 )                                 'concatenate_21[0][0]']
#
#  conv2d_221 (Conv2D)            (None, 128, 128, 96  9312        ['multiply_10[0][0]']
#                                 )
#
#  up_sampling2d_21 (UpSampling2D  (None, 128, 128, 64  0          ['activation_141[0][0]']
#  )                              )
#
#  batch_normalization_188 (Batch  (None, 128, 128, 96  384        ['conv2d_221[0][0]']
#  Normalization)                 )
#
#  concatenate_25 (Concatenate)   (None, 128, 128, 16  0           ['up_sampling2d_21[0][0]',
#                                 0)                                'batch_normalization_188[0][0]']
#
#  conv2d_222 (Conv2D)            (None, 128, 128, 32  46112       ['concatenate_25[0][0]']
#                                 )
#
#  batch_normalization_189 (Batch  (None, 128, 128, 32  128        ['conv2d_222[0][0]']
#  Normalization)                 )
#
#  activation_145 (Activation)    (None, 128, 128, 32  0           ['batch_normalization_189[0][0]']
#                                 )
#
#  conv2d_223 (Conv2D)            (None, 128, 128, 32  9248        ['activation_145[0][0]']
#                                 )
#
#  conv2d_224 (Conv2D)            (None, 128, 128, 32  5152        ['concatenate_25[0][0]']
#                                 )
#
#  batch_normalization_190 (Batch  (None, 128, 128, 32  128        ['conv2d_223[0][0]']
#  Normalization)                 )
#
#  batch_normalization_191 (Batch  (None, 128, 128, 32  128        ['conv2d_224[0][0]']
#  Normalization)                 )
#
#  dropout_55 (Dropout)           (None, 128, 128, 32  0           ['batch_normalization_190[0][0]']
#                                 )
#
#  add_66 (Add)                   (None, 128, 128, 32  0           ['batch_normalization_191[0][0]',
#                                 )                                 'dropout_55[0][0]']
#
#  activation_146 (Activation)    (None, 128, 128, 32  0           ['add_66[0][0]']
#                                 )
#
#  conv2d_225 (Conv2D)            (None, 128, 128, 16  528         ['activation_146[0][0]']
#                                 )
#
#  batch_normalization_192 (Batch  (None, 128, 128, 16  64         ['conv2d_225[0][0]']
#  Normalization)                 )
#
#  activation_147 (Activation)    (None, 128, 128, 16  0           ['batch_normalization_192[0][0]']
#                                 )
#
#  conv2d_227 (Conv2D)            (None, 128, 128, 16  272         ['activation_147[0][0]']
#                                 )
#
#  concatenate_22 (Concatenate)   (None, 256, 256, 48  0           ['activation_103[0][0]',
#                                 )                                 'activation_113[0][0]',
#                                                                   'activation_123[0][0]']
#
#  conv2d_transpose_11 (Conv2DTra  (None, 128, 128, 16  2320       ['conv2d_227[0][0]']
#  nspose)                        )
#
#  conv2d_226 (Conv2D)            (None, 128, 128, 16  3088        ['concatenate_22[0][0]']
#                                 )
#
#  add_67 (Add)                   (None, 128, 128, 16  0           ['conv2d_transpose_11[0][0]',
#                                 )                                 'conv2d_226[0][0]']
#
#  activation_148 (Activation)    (None, 128, 128, 16  0           ['add_67[0][0]']
#                                 )
#
#  conv2d_228 (Conv2D)            (None, 128, 128, 1)  17          ['activation_148[0][0]']
#
#  activation_149 (Activation)    (None, 128, 128, 1)  0           ['conv2d_228[0][0]']
#
#  up_sampling2d_22 (UpSampling2D  (None, 256, 256, 1)  0          ['activation_149[0][0]']
#  )
#
#  lambda_11 (Lambda)             (None, 256, 256, 48  0           ['up_sampling2d_22[0][0]']
#                                 )
#
#  multiply_11 (Multiply)         (None, 256, 256, 48  0           ['lambda_11[0][0]',
#                                 )                                 'concatenate_22[0][0]']
#
#  conv2d_229 (Conv2D)            (None, 256, 256, 48  2352        ['multiply_11[0][0]']
#                                 )
#
#  up_sampling2d_23 (UpSampling2D  (None, 256, 256, 32  0          ['activation_146[0][0]']
#  )                              )
#
#  batch_normalization_193 (Batch  (None, 256, 256, 48  192        ['conv2d_229[0][0]']
#  Normalization)                 )
#
#  concatenate_26 (Concatenate)   (None, 256, 256, 80  0           ['up_sampling2d_23[0][0]',
#                                 )                                 'batch_normalization_193[0][0]']
#
#  conv2d_230 (Conv2D)            (None, 256, 256, 16  11536       ['concatenate_26[0][0]']
#                                 )
#
#  batch_normalization_194 (Batch  (None, 256, 256, 16  64         ['conv2d_230[0][0]']
#  Normalization)                 )
#
#  activation_150 (Activation)    (None, 256, 256, 16  0           ['batch_normalization_194[0][0]']
#                                 )
#
#  conv2d_231 (Conv2D)            (None, 256, 256, 16  2320        ['activation_150[0][0]']
#                                 )
#
#  conv2d_232 (Conv2D)            (None, 256, 256, 16  1296        ['concatenate_26[0][0]']
#                                 )
#
#  batch_normalization_195 (Batch  (None, 256, 256, 16  64         ['conv2d_231[0][0]']
#  Normalization)                 )
#
#  batch_normalization_196 (Batch  (None, 256, 256, 16  64         ['conv2d_232[0][0]']
#  Normalization)                 )
#
#  dropout_56 (Dropout)           (None, 256, 256, 16  0           ['batch_normalization_195[0][0]']
#                                 )
#
#  add_68 (Add)                   (None, 256, 256, 16  0           ['batch_normalization_196[0][0]',
#                                 )                                 'dropout_56[0][0]']
#
#  activation_151 (Activation)    (None, 256, 256, 16  0           ['add_68[0][0]']
#                                 )
#
#  conv2d_233 (Conv2D)            (None, 256, 256, 4)  68          ['activation_151[0][0]']
#
#  batch_normalization_197 (Batch  (None, 256, 256, 4)  16         ['conv2d_233[0][0]']
#  Normalization)
#
#  input_9 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  activation_152 (Activation)    (None, 256, 256, 4)  0           ['batch_normalization_197[0][0]']
#
# ==================================================================================================
# Total params: 6,418,616
# Trainable params: 6,406,320
# Non-trainable params: 12,296
# __________________________________________________________________________________________________
# None
# ✅ Modelo cargado correctamente.

# %%
from sklearn.metrics import classification_report
from sklearn import metrics
import tensorflow as tf
predicted = np.expand_dims(test_images, 0)
prediction = (model.predict(test_list))
print(prediction.shape)
predicted_img = np.argmax(prediction, axis=3)[:,:,:]
y_test_pred = test_masks
# print(y_test.shape)
print(predicted_img.shape)
cm = metrics.confusion_matrix(y_test_pred.reshape(-1), predicted_img.reshape(-1))
print(cm, "\n")
print(classification_report(y_test_pred.reshape(-1), predicted_img.reshape(-1), digits=4))

from keras.metrics import MeanIoU
IOU_keras = MeanIoU(num_classes=4)
IOU_keras.update_state(y_test_pred.reshape(-1), predicted_img.reshape(-1))
print("Mean IoU = ", IOU_keras.result().numpy())
values = np.array(IOU_keras.get_weights()).reshape(4, 4)
class1_IoU = values[0,0]/(values[0,0] + values[0,1] + values[0,2] + values[0,3] + values[1,0] + values[2,0] + values[3,0])
class2_IoU = values[1,1]/(values[1,1] + values[1,0] + values[1,2] + values[1,3] + values[0,1] + values[2,1] + values[3,1])
class3_IoU = values[2,2]/(values[2,2] + values[2,0] + values[2,1] + values[2,3] + values[0,2] + values[1,2] + values[3,2])
class4_IoU = values[3,3]/(values[3,3] + values[3,0] + values[3,1] + values[3,2] + values[0,3] + values[1,3] + values[2,3])
print("class1 IoU = ", class1_IoU)
print("class2 IoU = ", class2_IoU)
print("class3 IoU = ", class3_IoU)
print("class4 IoU = ", class4_IoU)

m = tf.keras.metrics.Accuracy()
m.update_state(y_test_pred.reshape(-1), predicted_img.reshape(-1))
print('\n', 'Accuracy = ', m.result().numpy())

from sklearn.metrics import cohen_kappa_score
kappa_score = cohen_kappa_score(y_test_pred.reshape(-1), predicted_img.reshape(-1))
print("Kappa:", kappa_score)
# Out:
# 2/2 [==============================] - 6s 560ms/step
# (36, 256, 256, 4)
# (36, 256, 256)
# [[1583391   54957    1352     542]
#  [  19003  258653   70867    2269]
#  [   1222   10623  164054   21961]
#  [     96      32   14390  155884]]
#
#               precision    recall  f1-score   support
#
#            0     0.9873    0.9653    0.9762   1640242
#            1     0.7977    0.7373    0.7663    350792
#            2     0.6545    0.8291    0.7315    197860
#            3     0.8629    0.9148    0.8881    170402
#
#     accuracy                         0.9164   2359296
#    macro avg     0.8256    0.8617    0.8405   2359296
# weighted avg     0.9222    0.9164    0.9181   2359296
#
# Mean IoU =  0.7375201
# class1 IoU =  0.9535266
# class2 IoU =  0.6211588
# class3 IoU =  0.57670254
# class4 IoU =  0.79869246
#
#  Accuracy =  0.9163674
# Kappa: 0.8302050207461616

# %%
# Ramdomly check on test images
image_number = random.randint(0, len(test_images)-1)
predicted1 = np.expand_dims(test_list[0][image_number], 0)
predicted2 = np.expand_dims(test_list[1][image_number], 0)
predicted3 = np.expand_dims(test_list[2][image_number], 0)
predict_list = [predicted1, predicted2, predicted3]

prediction = (model.predict(predict_list))
predicted_img=np.argmax(prediction, axis=3)[0,:,:]
plt.figure(figsize=(12, 6))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(np.reshape((test_images[image_number, :, :, 2]), (256, 256, 1)))
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(np.reshape(test_masks[image_number], (256, 256, 1)))
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(np.reshape((predicted_img), (256, 256, 1)))
plt.show()
# Out:
# 1/1 [==============================] - 0s 219ms/step
