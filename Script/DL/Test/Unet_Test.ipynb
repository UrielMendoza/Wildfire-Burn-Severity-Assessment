# %%
import os
import glob
import numpy as np
from matplotlib import pyplot as plt
from osgeo import gdal
import pandas as pd
from keras.utils import to_categorical
import tensorflow as tf
from sklearn.utils import class_weight
import random

# %%
train_images = []
image_names = glob.glob(r"G:\Mi unidad\CG_Tesis_UrielMendoza\metodologia\datos\satelitales\Wildfire Burn Severity Assessment\Training\Image\Post/*.tif")
image_names.sort()
for img_path in image_names:
      tiff_image = gdal.Open(img_path, 0)
      band7 = tiff_image.GetRasterBand(7).ReadAsArray()
      band8 = tiff_image.GetRasterBand(8).ReadAsArray()
      band9 = tiff_image.GetRasterBand(9).ReadAsArray()

      X = np.stack((band9, band8, band7), axis=-1)
      train_images.append(X)

train_images = np.array(train_images)
print(np.mean(train_images))
X_train = train_images
print(X_train.shape)

train_masks = []
image_names = glob.glob(r"G:\Mi unidad\CG_Tesis_UrielMendoza\metodologia\datos\satelitales\Wildfire Burn Severity Assessment\Training\Mask/*.tif")
image_names.sort()
for img_path in image_names:
   tiff_image = gdal.Open(img_path, 0)
   band1 = tiff_image.GetRasterBand(1).ReadAsArray()
   train_masks.append(band1)

train_masks = np.array(train_masks)
y_train = train_masks
print(y_train.shape)

y_train_cat = to_categorical(train_masks, num_classes=4)
y_train_cat = y_train_cat.astype(int)
print(y_train_cat.shape)
# Out:
# c:\Users\urielm\anaconda3\envs\Wildfire-Burn-Severity-Assessment\lib\site-packages\osgeo\gdal.py:311: FutureWarning: Neither gdal.UseExceptions() nor gdal.DontUseExceptions() has been explicitly called. In GDAL 4.0, exceptions will be enabled by default.
#   warnings.warn(
# 1283.7584615587612
# (690, 256, 256, 3)
# (690, 256, 256)
# (690, 256, 256, 4)

# %%
#Sanity check, view few images
import random
import numpy as np
image_number = random.randint(0, len(train_images)-1)
plt.figure(figsize=(12, 6))
plt.subplot(121)
plt.imshow(np.reshape((train_images[image_number, :, :, 2]), (256, 256, 1)))
plt.subplot(122)
plt.imshow(np.reshape(train_masks[image_number], (256, 256, 1)))
plt.show()
print(image_number)
# Out:
# 460

# %%
test_images = []
image_names = glob.glob(r"G:\Mi unidad\CG_Tesis_UrielMendoza\metodologia\datos\satelitales\Wildfire Burn Severity Assessment\Testing\Image\Post/*.tif")
image_names.sort()
for img_path in image_names:
      tiff_image = gdal.Open(img_path, 0)
      band7 = tiff_image.GetRasterBand(7).ReadAsArray()
      band8 = tiff_image.GetRasterBand(8).ReadAsArray()
      band9 = tiff_image.GetRasterBand(9).ReadAsArray()

      X = np.stack((band9, band8, band7), axis=-1)
      test_images.append(X)

test_images = np.array(test_images)
print(np.mean(test_images))
print(test_images.shape)

test_masks = []
image_names = glob.glob(r"G:\Mi unidad\CG_Tesis_UrielMendoza\metodologia\datos\satelitales\Wildfire Burn Severity Assessment\Testing\Mask/*.tif")
image_names.sort()
for img_path in image_names:
   tiff_image = gdal.Open(img_path, 0)
   band1 = tiff_image.GetRasterBand(1).ReadAsArray()
   test_masks.append(band1)

test_masks = np.array(test_masks)
print(np.unique(test_masks))

y_test_cat = to_categorical(test_masks, num_classes=4)
y_test_cat = y_test_cat.astype(int)
print(y_test_cat.shape)
print(np.unique(y_test_cat))
# Out:
# 1314.3571367617008
# (36, 256, 256, 3)
# [0 1 2 3]
# (36, 256, 256, 4)
# [0 1]

# %%
# #Sanity check, view few images
image_number = random.randint(0, len(test_images)-1)
plt.figure(figsize=(12, 6))
plt.subplot(121)
plt.imshow(np.reshape((test_images[image_number, :, :, 2]), (256, 256, 1)))
plt.subplot(122)
plt.imshow(np.reshape(test_masks[image_number], (256, 256, 1)))
plt.show()
print(image_number)
# Out:
# 22

# %%
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate, Conv2DTranspose, BatchNormalization, Dropout, Activation, multiply
import tensorflow as tf
from tensorflow.keras import models, layers, regularizers
from tensorflow.keras import backend as K

def conv_block(x, filter_size, size, dropout, batch_norm=False):

    conv = layers.Conv2D(size, (filter_size, filter_size), padding="same")(x)
    if batch_norm is True:
        conv = layers.BatchNormalization(axis=3)(conv)
    conv = layers.Activation("relu")(conv)

    conv = layers.Conv2D(size, (filter_size, filter_size), padding="same")(conv)
    if batch_norm is True:
        conv = layers.BatchNormalization(axis=3)(conv)
    conv = layers.Activation("relu")(conv)

    if dropout > 0:
        conv = layers.Dropout(dropout)(conv)

    return conv


def repeat_elem(tensor, rep):
     return layers.Lambda(lambda x, repnum: K.repeat_elements(x, repnum, axis=3),
                          arguments={'repnum': rep})(tensor)

def gating_signal(input, out_size, batch_norm=False):

    x = layers.Conv2D(out_size, (1, 1), padding='same')(input)
    if batch_norm:
        x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    return x

def attention_block(x, gating, inter_shape):
    shape_x = K.int_shape(x)
    shape_g = K.int_shape(gating)

# Getting the x signal to the same shape as the gating signal
    theta_x = layers.Conv2D(inter_shape, (2, 2), strides=(2, 2), padding='same')(x)  # 16
    shape_theta_x = K.int_shape(theta_x)

# Getting the gating signal to the same number of filters as the inter_shape
    phi_g = layers.Conv2D(inter_shape, (1, 1), padding='same')(gating)
    upsample_g = layers.Conv2DTranspose(inter_shape, (3, 3),
                                 strides=(shape_theta_x[1] // shape_g[1], shape_theta_x[2] // shape_g[2]),
                                 padding='same')(phi_g)  # 16

    concat_xg = layers.add([upsample_g, theta_x])
    act_xg = layers.Activation('relu')(concat_xg)
    psi = layers.Conv2D(1, (1, 1), padding='same')(act_xg)
    sigmoid_xg = layers.Activation('sigmoid')(psi)
    shape_sigmoid = K.int_shape(sigmoid_xg)
    upsample_psi = layers.UpSampling2D(size=(shape_x[1] // shape_sigmoid[1], shape_x[2] // shape_sigmoid[2]))(sigmoid_xg)  # 32

    upsample_psi = repeat_elem(upsample_psi, shape_x[3])

    y = layers.multiply([upsample_psi, x])

    result = layers.Conv2D(shape_x[3], (1, 1), padding='same')(y)
    result_bn = layers.BatchNormalization()(result)
    return result_bn

def res_conv_block(x, filter_size, size, dropout, batch_norm=False):

    conv = layers.Conv2D(size, (filter_size, filter_size), padding='same')(x)
    if batch_norm is True:
        conv = layers.BatchNormalization(axis=3)(conv)
    conv = layers.Activation('relu')(conv)

    conv = layers.Conv2D(size, (filter_size, filter_size), padding='same')(conv)
    if batch_norm is True:
        conv = layers.BatchNormalization(axis=3)(conv)
    #conv = layers.Activation('relu')(conv)    #Activation before addition with shortcut
    if dropout > 0:
        conv = layers.Dropout(dropout)(conv)

    shortcut = layers.Conv2D(size, kernel_size=(1, 1), padding='same')(x)
    if batch_norm is True:
        shortcut = layers.BatchNormalization(axis=3)(shortcut)

    res_path = layers.add([shortcut, conv])
    res_path = layers.Activation('relu')(res_path)    #Activation after addition with shortcut (Original residual block)
    return res_path

# %%
def UNet(input_shape, NUM_CLASSES=4, dropout_rate=0.1, batch_norm=True):

    # network structure
    FILTER_NUM = 16 # number of filters for the first layer
    FILTER_SIZE = 3 # size of the convolutional filter
    UP_SAMP_SIZE = 2 # size of upsampling filters


    inputs = layers.Input(input_shape)

    # Downsampling layers
    # DownRes 1, convolution + pooling
    conv_128 = conv_block(inputs, FILTER_SIZE, FILTER_NUM, dropout_rate, batch_norm)
    pool_64 = layers.MaxPooling2D(pool_size=(2,2))(conv_128)
    # DownRes 2
    conv_64 = conv_block(pool_64, FILTER_SIZE, 2*FILTER_NUM, dropout_rate, batch_norm)
    pool_32 = layers.MaxPooling2D(pool_size=(2,2))(conv_64)
    # DownRes 3
    conv_32 = conv_block(pool_32, FILTER_SIZE, 4*FILTER_NUM, dropout_rate, batch_norm)
    pool_16 = layers.MaxPooling2D(pool_size=(2,2))(conv_32)
    # DownRes 4
    conv_16 = conv_block(pool_16, FILTER_SIZE, 8*FILTER_NUM, dropout_rate, batch_norm)
    pool_8 = layers.MaxPooling2D(pool_size=(2,2))(conv_16)
    # DownRes 5, convolution only
    conv_8 = conv_block(pool_8, FILTER_SIZE, 16*FILTER_NUM, dropout_rate, batch_norm)

    # Upsampling layers

    up_16 = layers.UpSampling2D(size=(UP_SAMP_SIZE, UP_SAMP_SIZE), data_format="channels_last")(conv_8)
    up_16 = layers.concatenate([up_16, conv_16], axis=3)
    up_conv_16 = conv_block(up_16, FILTER_SIZE, 8*FILTER_NUM, dropout_rate, batch_norm)
    # UpRes 7

    up_32 = layers.UpSampling2D(size=(UP_SAMP_SIZE, UP_SAMP_SIZE), data_format="channels_last")(up_conv_16)
    up_32 = layers.concatenate([up_32, conv_32], axis=3)
    up_conv_32 = conv_block(up_32, FILTER_SIZE, 4*FILTER_NUM, dropout_rate, batch_norm)
    # UpRes 8

    up_64 = layers.UpSampling2D(size=(UP_SAMP_SIZE, UP_SAMP_SIZE), data_format="channels_last")(up_conv_32)
    up_64 = layers.concatenate([up_64, conv_64], axis=3)
    up_conv_64 = conv_block(up_64, FILTER_SIZE, 2*FILTER_NUM, dropout_rate, batch_norm)
    # UpRes 9

    up_128 = layers.UpSampling2D(size=(UP_SAMP_SIZE, UP_SAMP_SIZE), data_format="channels_last")(up_conv_64)
    up_128 = layers.concatenate([up_128, conv_128], axis=3)
    up_conv_128 = conv_block(up_128, FILTER_SIZE, FILTER_NUM, dropout_rate, batch_norm)

    # 1*1 convolutional layers

    conv_final = layers.Conv2D(NUM_CLASSES, kernel_size=(1,1))(up_conv_128)
    conv_final = layers.BatchNormalization(axis=3)(conv_final)
    conv_final = layers.Activation('softmax')(conv_final)

    # Model
    model = models.Model(inputs, conv_final, name="UNet")
    print(model.summary())
    return model

# %%
import tensorflow as tf
import tensorflow.keras.backend as K


def categorical_mean_iou_loss(y_true, y_pred):
    y_true = tf.cast(y_true, y_pred.dtype)

    # Calculate intersection and union
    intersection = K.sum(K.abs(y_true * y_pred), axis=[1, 2])
    union = K.sum(y_true, axis=[1, 2]) + K.sum(y_pred, axis=[1, 2]) - intersection

    # Calculate mean IoU loss
    iou = (intersection + K.epsilon()) / (union + K.epsilon())
    mean_iou_loss = 1 - K.mean(iou)

    return mean_iou_loss

# %%
import tensorflow as tf

class MyMeanIOU(tf.keras.metrics.MeanIoU):
    def update_state(self, y_true, y_pred, sample_weight=None):
        print("Antes de casteo - y_pred dtype:", y_pred.dtype, "Shape:", y_pred.shape)
        print("Antes de casteo - y_true dtype:", y_true.dtype, "Shape:", y_true.shape)

        # Asegurar que ambos sean float32 antes de aplicar argmax
        y_true = tf.cast(y_true, dtype=tf.float32)
        y_pred = tf.cast(y_pred, dtype=tf.float32)

        # Aplicar argmax a la última dimensión y convertir a int32
        y_true = tf.argmax(y_true, axis=-1)  # Elimina la última dimensión
        y_pred = tf.argmax(y_pred, axis=-1)

        # Convertir a int32
        y_true = tf.cast(y_true, dtype=tf.int32)
        y_pred = tf.cast(y_pred, dtype=tf.int32)

        print("Después de casteo - y_pred dtype:", y_pred.dtype, "Shape:", y_pred.shape)
        print("Después de casteo - y_true dtype:", y_true.dtype, "Shape:", y_true.shape)

        # 🔹 Ahora y_true y y_pred deberían tener forma (batch_size, 256, 256)
        return super().update_state(y_true, y_pred, sample_weight)

# %%
# training
def get_model():
    return UNet((256, 256, 3))
#tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
#strategy = tf.distribute.TPUStrategy(tpu)
#with strategy.scope():
model = get_model()
model.compile(optimizer = 'adam', loss=categorical_mean_iou_loss, metrics = [MyMeanIOU(4)])
# tf.keras.losses.CategoricalCrossentropy()
# categorical_focal_loss(gamma=2.0, alpha=0.25)
# Out:
# Model: "UNet"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 256, 256, 16  448         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 256, 256, 16  64         ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 256, 256, 16  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 256, 256, 16  2320        ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 256, 256, 16  64         ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 256, 256, 16  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  dropout (Dropout)              (None, 256, 256, 16  0           ['activation_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 128, 128, 16  0           ['dropout[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 128, 128, 32  4640        ['max_pooling2d[0][0]']
#                                 )
#
#  batch_normalization_2 (BatchNo  (None, 128, 128, 32  128        ['conv2d_2[0][0]']
#  rmalization)                   )
#
#  activation_2 (Activation)      (None, 128, 128, 32  0           ['batch_normalization_2[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 128, 128, 32  9248        ['activation_2[0][0]']
#                                 )
#
#  batch_normalization_3 (BatchNo  (None, 128, 128, 32  128        ['conv2d_3[0][0]']
#  rmalization)                   )
#
#  activation_3 (Activation)      (None, 128, 128, 32  0           ['batch_normalization_3[0][0]']
#                                 )
#
#  dropout_1 (Dropout)            (None, 128, 128, 32  0           ['activation_3[0][0]']
#                                 )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 32)  0           ['dropout_1[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 64, 64, 64)   18496       ['max_pooling2d_1[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 64, 64, 64)  256         ['conv2d_4[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 64, 64, 64)   0           ['batch_normalization_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 64, 64, 64)   36928       ['activation_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 64, 64, 64)  256         ['conv2d_5[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 64, 64, 64)   0           ['batch_normalization_5[0][0]']
#
#  dropout_2 (Dropout)            (None, 64, 64, 64)   0           ['activation_5[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 64)  0           ['dropout_2[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 32, 32, 128)  73856       ['max_pooling2d_2[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 32, 32, 128)  512        ['conv2d_6[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 32, 32, 128)  0           ['batch_normalization_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 32, 32, 128)  147584      ['activation_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 32, 32, 128)  512        ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 32, 32, 128)  0           ['batch_normalization_7[0][0]']
#
#  dropout_3 (Dropout)            (None, 32, 32, 128)  0           ['activation_7[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 128)  0          ['dropout_3[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 16, 16, 256)  295168      ['max_pooling2d_3[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 16, 16, 256)  1024       ['conv2d_8[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 16, 16, 256)  0           ['batch_normalization_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 16, 16, 256)  590080      ['activation_8[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 16, 16, 256)  1024       ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_9 (Activation)      (None, 16, 16, 256)  0           ['batch_normalization_9[0][0]']
#
#  dropout_4 (Dropout)            (None, 16, 16, 256)  0           ['activation_9[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 32, 32, 256)  0           ['dropout_4[0][0]']
#
#  concatenate (Concatenate)      (None, 32, 32, 384)  0           ['up_sampling2d[0][0]',
#                                                                   'dropout_3[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 32, 32, 128)  442496      ['concatenate[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 32, 32, 128)  512        ['conv2d_10[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 32, 32, 128)  0           ['batch_normalization_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 32, 32, 128)  147584      ['activation_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 32, 32, 128)  512        ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 32, 32, 128)  0           ['batch_normalization_11[0][0]']
#
#  dropout_5 (Dropout)            (None, 32, 32, 128)  0           ['activation_11[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 64, 64, 128)  0          ['dropout_5[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 64, 64, 192)  0           ['up_sampling2d_1[0][0]',
#                                                                   'dropout_2[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 64, 64, 64)   110656      ['concatenate_1[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 64, 64, 64)  256         ['conv2d_12[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 64, 64, 64)   0           ['batch_normalization_12[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 64, 64, 64)   36928       ['activation_12[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 64, 64, 64)  256         ['conv2d_13[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 64, 64, 64)   0           ['batch_normalization_13[0][0]']
#
#  dropout_6 (Dropout)            (None, 64, 64, 64)   0           ['activation_13[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, 128, 128, 64  0          ['dropout_6[0][0]']
#                                 )
#
#  concatenate_2 (Concatenate)    (None, 128, 128, 96  0           ['up_sampling2d_2[0][0]',
#                                 )                                 'dropout_1[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 128, 128, 32  27680       ['concatenate_2[0][0]']
#                                 )
#
#  batch_normalization_14 (BatchN  (None, 128, 128, 32  128        ['conv2d_14[0][0]']
#  ormalization)                  )
#
#  activation_14 (Activation)     (None, 128, 128, 32  0           ['batch_normalization_14[0][0]']
#                                 )
#
#  conv2d_15 (Conv2D)             (None, 128, 128, 32  9248        ['activation_14[0][0]']
#                                 )
#
#  batch_normalization_15 (BatchN  (None, 128, 128, 32  128        ['conv2d_15[0][0]']
#  ormalization)                  )
#
#  activation_15 (Activation)     (None, 128, 128, 32  0           ['batch_normalization_15[0][0]']
#                                 )
#
#  dropout_7 (Dropout)            (None, 128, 128, 32  0           ['activation_15[0][0]']
#                                 )
#
#  up_sampling2d_3 (UpSampling2D)  (None, 256, 256, 32  0          ['dropout_7[0][0]']
#                                 )
#
#  concatenate_3 (Concatenate)    (None, 256, 256, 48  0           ['up_sampling2d_3[0][0]',
#                                 )                                 'dropout[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 256, 256, 16  6928        ['concatenate_3[0][0]']
#                                 )
#
#  batch_normalization_16 (BatchN  (None, 256, 256, 16  64         ['conv2d_16[0][0]']
#  ormalization)                  )
#
#  activation_16 (Activation)     (None, 256, 256, 16  0           ['batch_normalization_16[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 256, 256, 16  2320        ['activation_16[0][0]']
#                                 )
#
#  batch_normalization_17 (BatchN  (None, 256, 256, 16  64         ['conv2d_17[0][0]']
#  ormalization)                  )
#
#  activation_17 (Activation)     (None, 256, 256, 16  0           ['batch_normalization_17[0][0]']
#                                 )
#
#  dropout_8 (Dropout)            (None, 256, 256, 16  0           ['activation_17[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 256, 256, 4)  68          ['dropout_8[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 256, 256, 4)  16         ['conv2d_18[0][0]']
#  ormalization)
#
#  activation_18 (Activation)     (None, 256, 256, 4)  0           ['batch_normalization_18[0][0]']
#
# ==================================================================================================
# Total params: 1,968,580
# Trainable params: 1,965,628
# Non-trainable params: 2,952
# __________________________________________________________________________________________________
# None

# %%
model.summary()
# Out:
# Model: "UNet"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 256, 256, 16  448         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 256, 256, 16  64         ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 256, 256, 16  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 256, 256, 16  2320        ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 256, 256, 16  64         ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 256, 256, 16  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  dropout (Dropout)              (None, 256, 256, 16  0           ['activation_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 128, 128, 16  0           ['dropout[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 128, 128, 32  4640        ['max_pooling2d[0][0]']
#                                 )
#
#  batch_normalization_2 (BatchNo  (None, 128, 128, 32  128        ['conv2d_2[0][0]']
#  rmalization)                   )
#
#  activation_2 (Activation)      (None, 128, 128, 32  0           ['batch_normalization_2[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 128, 128, 32  9248        ['activation_2[0][0]']
#                                 )
#
#  batch_normalization_3 (BatchNo  (None, 128, 128, 32  128        ['conv2d_3[0][0]']
#  rmalization)                   )
#
#  activation_3 (Activation)      (None, 128, 128, 32  0           ['batch_normalization_3[0][0]']
#                                 )
#
#  dropout_1 (Dropout)            (None, 128, 128, 32  0           ['activation_3[0][0]']
#                                 )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 32)  0           ['dropout_1[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 64, 64, 64)   18496       ['max_pooling2d_1[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 64, 64, 64)  256         ['conv2d_4[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 64, 64, 64)   0           ['batch_normalization_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 64, 64, 64)   36928       ['activation_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 64, 64, 64)  256         ['conv2d_5[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 64, 64, 64)   0           ['batch_normalization_5[0][0]']
#
#  dropout_2 (Dropout)            (None, 64, 64, 64)   0           ['activation_5[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 64)  0           ['dropout_2[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 32, 32, 128)  73856       ['max_pooling2d_2[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 32, 32, 128)  512        ['conv2d_6[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 32, 32, 128)  0           ['batch_normalization_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 32, 32, 128)  147584      ['activation_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 32, 32, 128)  512        ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 32, 32, 128)  0           ['batch_normalization_7[0][0]']
#
#  dropout_3 (Dropout)            (None, 32, 32, 128)  0           ['activation_7[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 128)  0          ['dropout_3[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 16, 16, 256)  295168      ['max_pooling2d_3[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 16, 16, 256)  1024       ['conv2d_8[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 16, 16, 256)  0           ['batch_normalization_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 16, 16, 256)  590080      ['activation_8[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 16, 16, 256)  1024       ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_9 (Activation)      (None, 16, 16, 256)  0           ['batch_normalization_9[0][0]']
#
#  dropout_4 (Dropout)            (None, 16, 16, 256)  0           ['activation_9[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 32, 32, 256)  0           ['dropout_4[0][0]']
#
#  concatenate (Concatenate)      (None, 32, 32, 384)  0           ['up_sampling2d[0][0]',
#                                                                   'dropout_3[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 32, 32, 128)  442496      ['concatenate[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 32, 32, 128)  512        ['conv2d_10[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 32, 32, 128)  0           ['batch_normalization_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 32, 32, 128)  147584      ['activation_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 32, 32, 128)  512        ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 32, 32, 128)  0           ['batch_normalization_11[0][0]']
#
#  dropout_5 (Dropout)            (None, 32, 32, 128)  0           ['activation_11[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 64, 64, 128)  0          ['dropout_5[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 64, 64, 192)  0           ['up_sampling2d_1[0][0]',
#                                                                   'dropout_2[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 64, 64, 64)   110656      ['concatenate_1[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 64, 64, 64)  256         ['conv2d_12[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 64, 64, 64)   0           ['batch_normalization_12[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 64, 64, 64)   36928       ['activation_12[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 64, 64, 64)  256         ['conv2d_13[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 64, 64, 64)   0           ['batch_normalization_13[0][0]']
#
#  dropout_6 (Dropout)            (None, 64, 64, 64)   0           ['activation_13[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, 128, 128, 64  0          ['dropout_6[0][0]']
#                                 )
#
#  concatenate_2 (Concatenate)    (None, 128, 128, 96  0           ['up_sampling2d_2[0][0]',
#                                 )                                 'dropout_1[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 128, 128, 32  27680       ['concatenate_2[0][0]']
#                                 )
#
#  batch_normalization_14 (BatchN  (None, 128, 128, 32  128        ['conv2d_14[0][0]']
#  ormalization)                  )
#
#  activation_14 (Activation)     (None, 128, 128, 32  0           ['batch_normalization_14[0][0]']
#                                 )
#
#  conv2d_15 (Conv2D)             (None, 128, 128, 32  9248        ['activation_14[0][0]']
#                                 )
#
#  batch_normalization_15 (BatchN  (None, 128, 128, 32  128        ['conv2d_15[0][0]']
#  ormalization)                  )
#
#  activation_15 (Activation)     (None, 128, 128, 32  0           ['batch_normalization_15[0][0]']
#                                 )
#
#  dropout_7 (Dropout)            (None, 128, 128, 32  0           ['activation_15[0][0]']
#                                 )
#
#  up_sampling2d_3 (UpSampling2D)  (None, 256, 256, 32  0          ['dropout_7[0][0]']
#                                 )
#
#  concatenate_3 (Concatenate)    (None, 256, 256, 48  0           ['up_sampling2d_3[0][0]',
#                                 )                                 'dropout[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 256, 256, 16  6928        ['concatenate_3[0][0]']
#                                 )
#
#  batch_normalization_16 (BatchN  (None, 256, 256, 16  64         ['conv2d_16[0][0]']
#  ormalization)                  )
#
#  activation_16 (Activation)     (None, 256, 256, 16  0           ['batch_normalization_16[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 256, 256, 16  2320        ['activation_16[0][0]']
#                                 )
#
#  batch_normalization_17 (BatchN  (None, 256, 256, 16  64         ['conv2d_17[0][0]']
#  ormalization)                  )
#
#  activation_17 (Activation)     (None, 256, 256, 16  0           ['batch_normalization_17[0][0]']
#                                 )
#
#  dropout_8 (Dropout)            (None, 256, 256, 16  0           ['activation_17[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 256, 256, 4)  68          ['dropout_8[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 256, 256, 4)  16         ['conv2d_18[0][0]']
#  ormalization)
#
#  activation_18 (Activation)     (None, 256, 256, 4)  0           ['batch_normalization_18[0][0]']
#
# ==================================================================================================
# Total params: 1,968,580
# Trainable params: 1,965,628
# Non-trainable params: 2,952
# __________________________________________________________________________________________________

# %%
from keras_flops import get_flops
# Calculae FLOPS
flops = get_flops(model, batch_size=1)
print(f"FLOPS: {flops / 10 ** 9:.03} G")
print(flops)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 from keras_flops import get_flops
#       2 # Calculae FLOPS
#       3 flops = get_flops(model, batch_size=1)
#
# ModuleNotFoundError: No module named 'keras_flops'

# %%
from tensorflow.keras.models import load_model

modelo_path =r"C:\Users\urielm\Documents\GitHub\Wildfire-Burn-Severity-Assessment\Model\unet.h5"

try:
    modelo = load_model(modelo_path)
    print("✅ El archivo .h5 contiene la arquitectura y pesos.")
except:
    print("❌ El archivo .h5 solo contiene los pesos. Debes definir la arquitectura antes de cargarlos.")
# Out:
# ❌ El archivo .h5 solo contiene los pesos. Debes definir la arquitectura antes de cargarlos.

# %%
# ✅ Cargar la arquitectura del modelo y los pesos entrenados
model = UNet(input_shape=(256, 256, 3), NUM_CLASSES=4)
model.load_weights(modelo_path)

print("✅ Modelo cargado correctamente.")
# Out:
# Model: "UNet"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d_19 (Conv2D)             (None, 256, 256, 16  448         ['input_2[0][0]']
#                                 )
#
#  batch_normalization_19 (BatchN  (None, 256, 256, 16  64         ['conv2d_19[0][0]']
#  ormalization)                  )
#
#  activation_19 (Activation)     (None, 256, 256, 16  0           ['batch_normalization_19[0][0]']
#                                 )
#
#  conv2d_20 (Conv2D)             (None, 256, 256, 16  2320        ['activation_19[0][0]']
#                                 )
#
#  batch_normalization_20 (BatchN  (None, 256, 256, 16  64         ['conv2d_20[0][0]']
#  ormalization)                  )
#
#  activation_20 (Activation)     (None, 256, 256, 16  0           ['batch_normalization_20[0][0]']
#                                 )
#
#  dropout_9 (Dropout)            (None, 256, 256, 16  0           ['activation_20[0][0]']
#                                 )
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 128, 128, 16  0          ['dropout_9[0][0]']
#                                 )
#
#  conv2d_21 (Conv2D)             (None, 128, 128, 32  4640        ['max_pooling2d_4[0][0]']
#                                 )
#
#  batch_normalization_21 (BatchN  (None, 128, 128, 32  128        ['conv2d_21[0][0]']
#  ormalization)                  )
#
#  activation_21 (Activation)     (None, 128, 128, 32  0           ['batch_normalization_21[0][0]']
#                                 )
#
#  conv2d_22 (Conv2D)             (None, 128, 128, 32  9248        ['activation_21[0][0]']
#                                 )
#
#  batch_normalization_22 (BatchN  (None, 128, 128, 32  128        ['conv2d_22[0][0]']
#  ormalization)                  )
#
#  activation_22 (Activation)     (None, 128, 128, 32  0           ['batch_normalization_22[0][0]']
#                                 )
#
#  dropout_10 (Dropout)           (None, 128, 128, 32  0           ['activation_22[0][0]']
#                                 )
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 64, 64, 32)  0           ['dropout_10[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 64, 64, 64)   18496       ['max_pooling2d_5[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 64, 64, 64)  256         ['conv2d_23[0][0]']
#  ormalization)
#
#  activation_23 (Activation)     (None, 64, 64, 64)   0           ['batch_normalization_23[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 64, 64, 64)   36928       ['activation_23[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 64, 64, 64)  256         ['conv2d_24[0][0]']
#  ormalization)
#
#  activation_24 (Activation)     (None, 64, 64, 64)   0           ['batch_normalization_24[0][0]']
#
#  dropout_11 (Dropout)           (None, 64, 64, 64)   0           ['activation_24[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 32, 32, 64)  0           ['dropout_11[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 32, 32, 128)  73856       ['max_pooling2d_6[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 32, 32, 128)  512        ['conv2d_25[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 32, 32, 128)  0           ['batch_normalization_25[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 32, 32, 128)  147584      ['activation_25[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 32, 32, 128)  512        ['conv2d_26[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 32, 32, 128)  0           ['batch_normalization_26[0][0]']
#
#  dropout_12 (Dropout)           (None, 32, 32, 128)  0           ['activation_26[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 16, 16, 128)  0          ['dropout_12[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 16, 16, 256)  295168      ['max_pooling2d_7[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 16, 16, 256)  1024       ['conv2d_27[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 16, 16, 256)  0           ['batch_normalization_27[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 16, 16, 256)  590080      ['activation_27[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 16, 16, 256)  1024       ['conv2d_28[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 16, 16, 256)  0           ['batch_normalization_28[0][0]']
#
#  dropout_13 (Dropout)           (None, 16, 16, 256)  0           ['activation_28[0][0]']
#
#  up_sampling2d_4 (UpSampling2D)  (None, 32, 32, 256)  0          ['dropout_13[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 32, 32, 384)  0           ['up_sampling2d_4[0][0]',
#                                                                   'dropout_12[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 32, 32, 128)  442496      ['concatenate_4[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 32, 32, 128)  512        ['conv2d_29[0][0]']
#  ormalization)
#
#  activation_29 (Activation)     (None, 32, 32, 128)  0           ['batch_normalization_29[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 32, 32, 128)  147584      ['activation_29[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 32, 32, 128)  512        ['conv2d_30[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 32, 32, 128)  0           ['batch_normalization_30[0][0]']
#
#  dropout_14 (Dropout)           (None, 32, 32, 128)  0           ['activation_30[0][0]']
#
#  up_sampling2d_5 (UpSampling2D)  (None, 64, 64, 128)  0          ['dropout_14[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 64, 64, 192)  0           ['up_sampling2d_5[0][0]',
#                                                                   'dropout_11[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 64, 64, 64)   110656      ['concatenate_5[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 64, 64, 64)  256         ['conv2d_31[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 64, 64, 64)   0           ['batch_normalization_31[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 64, 64, 64)   36928       ['activation_31[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 64, 64, 64)  256         ['conv2d_32[0][0]']
#  ormalization)
#
#  activation_32 (Activation)     (None, 64, 64, 64)   0           ['batch_normalization_32[0][0]']
#
#  dropout_15 (Dropout)           (None, 64, 64, 64)   0           ['activation_32[0][0]']
#
#  up_sampling2d_6 (UpSampling2D)  (None, 128, 128, 64  0          ['dropout_15[0][0]']
#                                 )
#
#  concatenate_6 (Concatenate)    (None, 128, 128, 96  0           ['up_sampling2d_6[0][0]',
#                                 )                                 'dropout_10[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 128, 128, 32  27680       ['concatenate_6[0][0]']
#                                 )
#
#  batch_normalization_33 (BatchN  (None, 128, 128, 32  128        ['conv2d_33[0][0]']
#  ormalization)                  )
#
#  activation_33 (Activation)     (None, 128, 128, 32  0           ['batch_normalization_33[0][0]']
#                                 )
#
#  conv2d_34 (Conv2D)             (None, 128, 128, 32  9248        ['activation_33[0][0]']
#                                 )
#
#  batch_normalization_34 (BatchN  (None, 128, 128, 32  128        ['conv2d_34[0][0]']
#  ormalization)                  )
#
#  activation_34 (Activation)     (None, 128, 128, 32  0           ['batch_normalization_34[0][0]']
#                                 )
#
#  dropout_16 (Dropout)           (None, 128, 128, 32  0           ['activation_34[0][0]']
#                                 )
#
#  up_sampling2d_7 (UpSampling2D)  (None, 256, 256, 32  0          ['dropout_16[0][0]']
#                                 )
#
#  concatenate_7 (Concatenate)    (None, 256, 256, 48  0           ['up_sampling2d_7[0][0]',
#                                 )                                 'dropout_9[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 256, 256, 16  6928        ['concatenate_7[0][0]']
#                                 )
#
#  batch_normalization_35 (BatchN  (None, 256, 256, 16  64         ['conv2d_35[0][0]']
#  ormalization)                  )
#
#  activation_35 (Activation)     (None, 256, 256, 16  0           ['batch_normalization_35[0][0]']
#                                 )
#
#  conv2d_36 (Conv2D)             (None, 256, 256, 16  2320        ['activation_35[0][0]']
#                                 )
#
#  batch_normalization_36 (BatchN  (None, 256, 256, 16  64         ['conv2d_36[0][0]']
#  ormalization)                  )
#
#  activation_36 (Activation)     (None, 256, 256, 16  0           ['batch_normalization_36[0][0]']
#                                 )
#
#  dropout_17 (Dropout)           (None, 256, 256, 16  0           ['activation_36[0][0]']
#                                 )
#
#  conv2d_37 (Conv2D)             (None, 256, 256, 4)  68          ['dropout_17[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 256, 256, 4)  16         ['conv2d_37[0][0]']
#  ormalization)
#
#  activation_37 (Activation)     (None, 256, 256, 4)  0           ['batch_normalization_37[0][0]']
#
# ==================================================================================================
# Total params: 1,968,580
# Trainable params: 1,965,628
# Non-trainable params: 2,952
# __________________________________________________________________________________________________
# None
# ✅ Modelo cargado correctamente.

# %%
from sklearn.metrics import classification_report
from sklearn import metrics
import tensorflow as tf
predicted = np.expand_dims(test_images, 0)
prediction = (model.predict(test_images))
print(prediction.shape)
predicted_img = np.argmax(prediction, axis=3)[:,:,:]
y_test_pred = test_masks
print(predicted_img.shape)
cm = metrics.confusion_matrix(y_test_pred.reshape(-1), predicted_img.reshape(-1))
print(cm, "\n")
print(classification_report(y_test_pred.reshape(-1), predicted_img.reshape(-1), digits=4))

from keras.metrics import MeanIoU
IOU_keras = MeanIoU(num_classes=4)
IOU_keras.update_state(y_test_pred.reshape(-1), predicted_img.reshape(-1))
print("Mean IoU = ", IOU_keras.result().numpy())
values = np.array(IOU_keras.get_weights()).reshape(4, 4)
class1_IoU = values[0,0]/(values[0,0] + values[0,1] + values[0,2] + values[0,3] + values[1,0] + values[2,0] + values[3,0])
class2_IoU = values[1,1]/(values[1,1] + values[1,0] + values[1,2] + values[1,3] + values[0,1] + values[2,1] + values[3,1])
class3_IoU = values[2,2]/(values[2,2] + values[2,0] + values[2,1] + values[2,3] + values[0,2] + values[1,2] + values[3,2])
class4_IoU = values[3,3]/(values[3,3] + values[3,0] + values[3,1] + values[3,2] + values[0,3] + values[1,3] + values[2,3])
print("class1 IoU = ", class1_IoU)
print("class2 IoU = ", class2_IoU)
print("class3 IoU = ", class3_IoU)
print("class4 IoU = ", class4_IoU)

m = tf.keras.metrics.Accuracy()
m.update_state(y_test_pred.reshape(-1), predicted_img.reshape(-1))
print('\n', 'Accuracy = ', m.result().numpy())

from sklearn.metrics import cohen_kappa_score
kappa_score = cohen_kappa_score(y_test_pred.reshape(-1), predicted_img.reshape(-1))
print("Kappa:", kappa_score)
# Out:
# 2/2 [==============================] - 2s 196ms/step
# (36, 256, 256, 4)
# (36, 256, 256)
# [[1572574   63548    3482     638]
#  [  29256  242807   66852   11877]
#  [   5483   58428   98837   35112]
#  [   2190    3022   38848  126342]]
#
#               precision    recall  f1-score   support
#
#            0     0.9771    0.9587    0.9678   1640242
#            1     0.6602    0.6922    0.6758    350792
#            2     0.4751    0.4995    0.4870    197860
#            3     0.7262    0.7414    0.7338    170402
#
#     accuracy                         0.8649   2359296
#    macro avg     0.7096    0.7230    0.7161   2359296
# weighted avg     0.8697    0.8649    0.8672   2359296
#
# Mean IoU =  0.5873332
# class1 IoU =  0.9376349
# class2 IoU =  0.5103239
# class3 IoU =  0.32190058
# class4 IoU =  0.5794734
#
#  Accuracy =  0.8649021
# Kappa: 0.7241889023318664

# %%
# 📌 Verificar valores de la predicción
print(f"🔹 Forma de la predicción: {prediction.shape}")
print(f"🔹 Valores únicos en la predicción: {np.unique(prediction)}")
# Out:
# 🔹 Forma de la predicción: (36, 256, 256, 4)
# 🔹 Valores únicos en la predicción: [2.1984058e-20 2.8298182e-19 4.2072427e-19 ... 9.9999976e-01 9.9999988e-01
#  1.0000000e+00]

# %%
#Randomly check on train images
image_number = random.randint(0, len(train_images)-1)
predicted = np.expand_dims(train_images[image_number], 0)
prediction = (model.predict(predicted))
predicted_img=np.argmax(prediction, axis=3)[0,:,:]
plt.figure(figsize=(12, 6))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(np.reshape((train_images[image_number, :, :, 2]), (256, 256, 1)))
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(np.reshape(train_masks[image_number], (256, 256, 1)))
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(np.reshape((predicted_img), (256, 256, 1)))
plt.show()
# Out:
# 1/1 [==============================] - 0s 133ms/step
